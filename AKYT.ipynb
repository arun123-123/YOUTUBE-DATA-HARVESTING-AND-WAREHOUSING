# %%
print("Hello World")
# Out:
# Hello World

# %%
#UCTS5xUZP5l5J7DzjjyEWUKA - Hey Jane
#UCy7jKqbTj9DqgIeaQT0_png - lee

# %%
"AIzaSyDU3WcG-OmUZJquY056E5aMsyWOdgwCNXc"
# Out:
# 'AIzaSyDU3WcG-OmUZJquY056E5aMsyWOdgwCNXc'

# %%
from googleapiclient.discovery import build
import pymongo
import psycopg2
import pandas as pd
import streamlit as st

# %% [markdown]
# ##### API CONNECTION

# %%
#API key connection

def Api_connect():
    Api_Id="AIzaSyC7uiKclPszYlB29VyJHjz-jC8rOSHDDIs"

    api_service_name="youtube"
    api_version="v3"

    youtube=build(api_service_name,api_version,developerKey=Api_Id)

    return youtube

youtube=Api_connect()

# %% [markdown]
# ##### CHANNEL INFORMATION

# %%
#get channels information

def get_channel_info(channel_id):
    request=youtube.channels().list(
                    part="snippet,ContentDetails,statistics",
                    id=channel_id
    )
    response=request.execute()

    for i in response['items']:
        data=dict(Channel_Name=i["snippet"]["title"],
                Channel_Id=i["id"],
                Subscribers=i['statistics']['subscriberCount'],
                Views=i["statistics"]["viewCount"],
                Total_Videos=i["statistics"]["videoCount"],
                Channel_Description=i["snippet"]["description"],
                Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"])
    return data

# %%
channel_information = get_channel_info("UCJcCB-QYPIBcbKcBQOTwhiA")

# %%
channel_information
# Out:
# {'Channel_Name': 'Vj Siddhu Vlogs',
#  'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#  'Subscribers': '3600000',
#  'Views': '743017547',
#  'Total_Videos': '277',
#  'Channel_Description': 'Hello guys! Welcome to my channel! !\n\nMy channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. \n\nGet ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected!  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n______________________________\n\nDigital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n',
#  'Playlist_Id': 'UUJcCB-QYPIBcbKcBQOTwhiA'}

# %% [markdown]
# ##### VIDEO ID'S

# %%
#get video ids

def get_videos_ids(channel_id):
    video_ids=[]
    response=youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:
        response1=youtube.playlistItems().list(
                                            part='snippet',
                                            playlistId=Playlist_Id,
                                            maxResults=50,
                                            pageToken=next_page_token).execute()
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
        next_page_token=response1.get('nextPageToken')

        if next_page_token is None:
            break
    return video_ids

# %%
video_ids = get_videos_ids("UCJcCB-QYPIBcbKcBQOTwhiA")

# %%
video_ids
# Out:
# ['dEyhsXExCQ4',
#  'AnZJvhR-TG0',
#  'U6Vzawt5pd8',
#  'GWx3nMbWOd8',
#  'lz-SC3NwSGY',
#  'JXCajlLdHMQ',
#  'w8EoQVnZPcQ',
#  'Ap9FTyrmVvg',
#  'dLSHRh0UdHg',
#  '8QF_UFx14_8',
#  'yKizwXo57UQ',
#  'd28X__L7RkI',
#  'pVb_AMqoqaU',
#  'zXzMYAzdjkI',
#  '3YVsmHCtQX0',
#  'gxBURlXYkUw',
#  'bbEnUUqYRQY',
#  'lAVwlqGC2Do',
#  'h6hVTkLUCf4',
#  'z9rbAGIMXB4',
#  'zmsF_dsHkzM',
#  'V_gtVAbGRkQ',
#  'Gt5yZJB1zAQ',
#  'KDYog6NeA9o',
#  '7zBQFocSBCA',
#  'Msus5xgBIJU',
#  '5PlhmtECy1s',
#  'pkBYegMQwyI',
#  '7eeQz7tVXrI',
#  'Cw8eKXPVXKU',
#  'BwUXFWtpw4Q',
#  '43JAaDhcxw4',
#  'DGb_5290SnI',
#  'cOm-AwFEG18',
#  '1r8JXIleOSw',
#  'Jr-YMNdK9eo',
#  '413eWWNmTK8',
#  '7Y9f70E4G8g',
#  'Iu_Gp2BuXFg',
#  '3UtjGMYW1v8',
#  'us8ueJD3P2c',
#  '4Kn3z9XL5-U',
#  'SQ3nIQKKSqI',
#  'og8KctUjUOw',
#  '1zQA9aiXfdo',
#  'CWNAgG2Xq4s',
#  'fJ1qMl5Nj1Q',
#  'u2kCZUTg8nc',
#  '_EgW-vgGrpw',
#  'Irtf3Nmmxr0',
#  'Oo0ZDURCih4',
#  'eucyU8UxHDU',
#  'Kq2xX11K7L4',
#  'dS1Q1Ftz7VM',
#  'PEINsiHG_D4',
#  'VU5G_t1kkoo',
#  'Nsag8TwyQQY',
#  'zEmJc23dne4',
#  'ZPnL0wnXDuA',
#  '0EmQAi5eOOA',
#  '5qls34NYAOI',
#  'sYGZt2vIkvI',
#  '1E-fbi6e0ts',
#  'wa1B5M_kBD0',
#  'tO-uV2b1TpQ',
#  '-Sc9x9fObPU',
#  '0ykmSriLM2o',
#  'ipdWI-ydpwc',
#  'Mr84QSXiIaw',
#  'jdK_AkFQ1vs',
#  'jCEurjwsR8c',
#  'PHJY0JXWdUI',
#  'kbQeitxaERo',
#  'jFsnt2e4Mqg',
#  'HhPsKvqiApM',
#  'hfv64eowOSM',
#  '6jgAkfPGtFk',
#  '9CWt8AeJKxw',
#  'nYQvS5BfbsY',
#  'eS5_ZVbZack',
#  'RTYolQV8ano',
#  'zycx4PVnUL8',
#  'w5SZw42JIfs',
#  'p9p8_dQtVGY',
#  'ivULarI44Mk',
#  '2S-EHMUckxQ',
#  '6UYEslZ_pvI',
#  'WXfHkT8Xej0',
#  '-GLXGUfFxL0',
#  '2hOk09iSAKM',
#  'QCYDdAnHZzg',
#  'YUM00QJKC3Y',
#  'DwrVC5aBv3o',
#  '7Qe8ZKBt6vw',
#  'alzwxkS9ckc',
#  'Kw13BsXwA9U',
#  'E7u4wZfHZ2w',
#  'sHo4-P-Dads',
#  'tOrmrbJL0gc',
#  'b_cKMNgxaVI',
#  'BvLacrdqmts',
#  'TP9pxgkanMg',
#  'X7RcRT5k3k4',
#  'Bi_Ot8_yDpo',
#  'bZvlJUkprrg',
#  'cL9hOBbrk2A',
#  'HdmDYVko7nI',
#  'wjrMQnwEiUo',
#  '3uugSgVkcxA',
#  'AMbzmzDxJP4',
#  'M9hbj3phdT8',
#  'c-GfFMdwofE',
#  '_I4Zax5Wkwk',
#  'tLcdCRaPLZ8',
#  'tAjwXyaZTZM',
#  't_Y-19h82r0',
#  '5dy2zAlVAuM',
#  'rTPXt-Wh-D8',
#  'Q3-1Wj51Hq4',
#  '2xnCG2OuqfE',
#  'yQ45vIHpWxc',
#  '1zBuKn3KXFg',
#  'fc1bD5SQvkk',
#  'kn4vQ-uG4Kw',
#  'U5saYYiQ5b8',
#  's15KKauqS4E',
#  'UTXYgCKS7Hg',
#  'rq7Rp6_3aXk',
#  'yScV-YwTnEk',
#  'H7K4N8mSCc4',
#  'p5Ix1Faz1Hw',
#  'MBR4kefV3wI',
#  '1PrJNVW16UY',
#  'EKyT8SVo89s',
#  'XDF6sPFPO3U',
#  'PXzT3bVlFNk',
#  'tIMDNFKKq74',
#  '3Hi7I81gtXs',
#  'Ked0saxns6Q',
#  'baxuANxNlfI',
#  'ZoI2wfj_OX0',
#  'PKUCLg6xOeY',
#  'u9tDHRYUJok',
#  'qPyhETU3VjA',
#  'sCq4qwwVmx0',
#  '301HsAA3z1c',
#  'szatZqT3B94',
#  'ObJvAJbe8HY',
#  'c1HX_EbZYAo',
#  'o-Cc6jq916M',
#  'RMwC_4oxKT0',
#  'cu_kqf70vEg',
#  '6ZX8gywf6sQ',
#  'oVHwoZaMD-s',
#  'fT9yAjUHzwQ',
#  'qltm-ak_OKo',
#  'G7gaf4MjN4o',
#  'zXWvYpc3QCE',
#  'HN54x-eShFU',
#  'J9-hDP9Lu1g',
#  '4NppfA06-_s',
#  '6l55q7r4MGU',
#  'FV9xIo7Umlg',
#  'dbsv8HPT2Ww',
#  '3q6-_eROVDA',
#  'zcaOimCOsmQ',
#  'YrXAUN3p1IM',
#  'nXklZKUebSs',
#  'tLMoqfR-qCQ',
#  'QIGYf2erUHo',
#  'NPMjsLOPN70',
#  'EQKYyL6ycSM',
#  '1dOwdBY3szA',
#  'VqDTwjnY8lg',
#  'EUeu-GJyuYw',
#  's5RDMG_tUao',
#  'dSPbSzYYDWM',
#  '8Han8BxvowY',
#  'kDpxPWeRnc8',
#  'P9HFWTJ4-xE',
#  'uyWVgA5tyrM',
#  'W2gKC1ZIQGU',
#  'sqqn5v1lgYI',
#  'clW5w4Da6bo',
#  'owq8pBKJjN0',
#  'Kw_Wq3kGmYg',
#  '_KdnWXvqX9w',
#  'snsgnHhqzbA',
#  'SMiDWZfHEXI',
#  'NorgkUtR6qk',
#  '-uNo-wCb6uc',
#  'iWxDeOPZL1w',
#  'ilOdl7yrF_Y',
#  'F_5yH9-9cig',
#  'z94RB8446A0',
#  'QvLelz6dPTY',
#  'VW8HFecxb68',
#  'bfsPCK5BlXI',
#  'EiXBbGZZnYY',
#  '1qAHPXYvdiA',
#  'xdeVjROwFEc',
#  'bX83aS2wClI',
#  'bIr9h7jtXXk',
#  'mLiuvVXfUII',
#  'cewmYVENXjk',
#  '533epbdavzA',
#  'xMd4Q8hzldM',
#  'yNNkkuGNDhQ',
#  'E3H0vX8x9M8',
#  'i87u4H95el8',
#  'z3TdxPFm-L0',
#  'te5MIYgzFRo',
#  'ssc8mX5eByI',
#  '6htKQ9m5gVM',
#  'kJmUaD6RnhQ',
#  'XeEQ5shaG88',
#  'ksyBX4Ix32s',
#  'hTTFUvpxrqE',
#  'GavbgrCfSiw',
#  't_8zbyPykgQ',
#  'VJaAKKPLmsg',
#  'ZGLIUS9WB8A',
#  'U_Sj6vRJkLQ',
#  'WDAOs8vXf4M',
#  'OecMmdkX4L0',
#  '8zo-lb7LvGA',
#  'qivlE1Hy3dQ',
#  'CmQgdGcqy_s',
#  '0gP4BWpl5Lw',
#  'hBLoCsCmXkE',
#  'dQf5xtW5UYk',
#  'WPLHElwsPPU',
#  '4jMwYwtMR3s',
#  '3OcucZQcG_8',
#  'csv6Y8x6BRU',
#  'd52kp676npI',
#  'GfmQ6mzzly0',
#  '9jovCSAeaBo',
#  'TyMsPyNQcA8',
#  'Ucx2i_TufNk',
#  'FVCZ8NPAytY',
#  'YHv9RXnr7XY',
#  'nO43MjCLW0A',
#  'TrisAUXFK8o',
#  '8yAsHJrGFLg',
#  'L7AzOlTLHd4',
#  'UFnxxxldXqg',
#  'R_dzTQywdek',
#  '1OKP6dWX_xM',
#  'igvUpCEALzI',
#  'r7Rx9I0Al8E',
#  '0IVBovKGSdE',
#  'v1arwXMvv1o',
#  'Oi_PI9mWT0A',
#  'zlKEjwZ1WCY',
#  '-XC-ZZQTFTc',
#  'm3MLYRgIb6k',
#  'vZGsef4gAZg',
#  'P6aeNk0KqhU',
#  'FZOWUCLG9cI',
#  '55FJ8S5GJQw',
#  'jpxNuluiy8U',
#  'yfwnpF_YB38',
#  'ji2qL2k18P4',
#  '3TYJLzh47zE',
#  'nMMPnXQpTB4',
#  'TrIvXer5EpY',
#  'mTj7xYaG4k4',
#  '5PN73jENxzA',
#  'SPyVuauAYrU',
#  'UKbg8CEEmmA',
#  'AJ4J6soRGQg',
#  'FBZFmBcm-lw',
#  '7f8GkhCakxs',
#  'N6hC1j2p8HI',
#  '2KtPwmjqtBk',
#  'OkuCdKIYzX0']

# %% [markdown]
# ##### VIDEO INFORMATION

# %%
#get video information
def get_video_info(video_ids):
    video_data=[]
    for video_id in video_ids:
        request=youtube.videos().list(
            part="snippet,ContentDetails,statistics",
            id=video_id
        )
        response=request.execute()

        for item in response["items"]:
            data=dict(Channel_Name=item['snippet']['channelTitle'],
                    Channel_Id=item['snippet']['channelId'],
                    Video_Id=item['id'],
                    Title=item['snippet']['title'],
                    Tags=item['snippet'].get('tags'),
                    Thumbnail=item['snippet']['thumbnails']['default']['url'],
                    Description=item['snippet'].get('description'),
                    Published_Date=item['snippet']['publishedAt'],
                    Duration=item['contentDetails']['duration'],
                    Views=item['statistics'].get('viewCount'),
                    Likes=item['statistics'].get('likeCount'),
                    Comments=item['statistics'].get('commentCount'),
                    Favorite_Count=item['statistics']['favoriteCount'],
                    Definition=item['contentDetails']['definition'],
                    Caption_Status=item['contentDetails']['caption']
                    )
            video_data.append(data)    
    return video_data

# %%
video_information = get_video_info(video_ids)

# %%
video_information
# Out:
# [{'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Title': '140 அடி பிரம்மாண்ட முருகர்✨🤩| Malaysia Series | Ep - 08 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia',
#    'virundhu',
#    'siddhu virundhu',
#    'vj sidhu virundhu',
#    'malaysia virundhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/dEyhsXExCQ4/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiaseries #episode8\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-15T09:30:07Z',
#   'Duration': 'PT15M5S',
#   'Views': '949983',
#   'Likes': '92685',
#   'Comments': '790',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Title': 'Game-ஏ வாய்-ல தான் 🙄🤣| Malaysia Virundhu | Ep - 07 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia',
#    'virundhu',
#    'siddhu virundhu',
#    'vj sidhu virundhu',
#    'malaysia virundhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/AnZJvhR-TG0/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode7\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-13T09:30:07Z',
#   'Duration': 'PT6M48S',
#   'Views': '1038662',
#   'Likes': '91017',
#   'Comments': '925',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Title': 'என் நெஞ்சில் குடியிருக்கும்...🤩 | Malaysia Virundhu Ep - 06 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia',
#    'virundhu',
#    'siddhu virundhu',
#    'vj sidhu virundhu',
#    'malaysia virundhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/U6Vzawt5pd8/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode6\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-11T09:30:08Z',
#   'Duration': 'PT23M19S',
#   'Views': '1761236',
#   'Likes': '139622',
#   'Comments': '1560',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Title': 'Biriyani Ready, Are You Ready? 🍗🤩 | Malaysia Virundhu Ep - 05 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia',
#    'virundhu',
#    'siddhu virundhu',
#    'vj sidhu virundhu',
#    'malaysia virundhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/GWx3nMbWOd8/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode5 #siddhu #vjsiddhu #virundhu\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-10T04:30:07Z',
#   'Duration': 'PT14M4S',
#   'Views': '1702412',
#   'Likes': '133405',
#   'Comments': '1028',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Title': 'ஆஹா! அழ வச்சிருவாங்க போலையே🥺❤️ | Malaysia Virundhu Ep - 04 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'Tamil travel vlog',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'lifestyle vlogs',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia',
#    'virundhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/lz-SC3NwSGY/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode4 #siddhu #vjsiddhu #virundhu \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-08T09:30:07Z',
#   'Duration': 'PT20M21S',
#   'Views': '1787957',
#   'Likes': '154981',
#   'Comments': '2130',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'JXCajlLdHMQ',
#   'Title': 'VJ Siddhu Vlogs-ல பொண்ணா 😱🙋🏻\u200d♀️| Malaysia Virundhu | Ep - 03 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'Tamil travel vlog',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'lifestyle vlogs',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia'],
#   'Thumbnail': 'https://i.ytimg.com/vi/JXCajlLdHMQ/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode3\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-06T09:30:07Z',
#   'Duration': 'PT13M28S',
#   'Views': '2126165',
#   'Likes': '151866',
#   'Comments': '1482',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'w8EoQVnZPcQ',
#   'Title': 'விடிஞ்சா Function குடுக்குறாங்க Tension🤕 | Malaysia Virundhu | Ep - 02 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'Tamil travel vlog',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'lifestyle vlogs',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia'],
#   'Thumbnail': 'https://i.ytimg.com/vi/w8EoQVnZPcQ/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode2 \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-04T10:00:07Z',
#   'Duration': 'PT18M',
#   'Views': '2309071',
#   'Likes': '156701',
#   'Comments': '1046',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'Ap9FTyrmVvg',
#   'Title': 'Malaysia மக்களே We are coming 🤩🥳 | Malaysia Virundhu | Ep - 01 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'VJ Siddhu Malaysia series',
#    'Tamil travel vlog',
#    'exploring Malaysia',
#    'Tamil vlogger',
#    'lifestyle vlogs',
#    'travel series',
#    'Tamil YouTuber',
#    'Malaysia tourism',
#    'vj siddu',
#    'vj siddhu malaysia virundhu',
#    'vj siddhu malaysia series',
#    'vj siddhu virundhu',
#    'vj siddhu malaysia trip',
#    'vj siddhu malaysia'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Ap9FTyrmVvg/default.jpg',
#   'Description': '#vjsiddhuvlogs #malaysia #malaysiavirundhu #episode1  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-03T04:30:08Z',
#   'Duration': 'PT13M29S',
#   'Views': '2281074',
#   'Likes': '154670',
#   'Comments': '945',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'dLSHRh0UdHg',
#   'Title': 'அவுளோ பயம் உயிர்மேல  😱 | Bali Ep- 13 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'bali vlog',
#    'siddhu bali series',
#    'bali travel',
#    'bali travel vlog',
#    'bali travel vlog tamil',
#    'bali'],
#   'Thumbnail': 'https://i.ytimg.com/vi/dLSHRh0UdHg/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #balitravel #giliisland #baliseries #episode13 \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-11-01T10:30:07Z',
#   'Duration': 'PT21M33S',
#   'Views': '1969744',
#   'Likes': '138768',
#   'Comments': '1693',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': '8QF_UFx14_8',
#   'Title': 'பொறுத்தது போதும் பொரிச்சு எடு 🤩🥳 | Diwali Special | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'vj siddhu latest vlog',
#    'vj siddhu latest',
#    'vj siddhu new video',
#    'vj siddhu funny',
#    'vj siddhu harshath khan',
#    'harshath khan',
#    'vj siddhu comedy vlog',
#    'vj siddhu cooking',
#    'vj siddhu vlogs',
#    'cooking vlog',
#    'vj siddhu cooking vlog',
#    'diwali special'],
#   'Thumbnail': 'https://i.ytimg.com/vi/8QF_UFx14_8/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #funcooking #cookingvlog #diwali #diwalicooking \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-30T10:10:08Z',
#   'Duration': 'PT18M57S',
#   'Views': '2095408',
#   'Likes': '130408',
#   'Comments': '1309',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'yKizwXo57UQ',
#   'Title': 'Chocolate முறுக்கு சாப்பிட்டா கிறுக்கு💥🥳| Diwali Special | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'vj siddhu latest vlog',
#    'vj siddhu latest',
#    'vj siddhu new video',
#    'vj siddhu funny',
#    'vj siddhu harshath khan',
#    'harshath khan',
#    'vj siddhu comedy vlog',
#    'vj siddhu cooking',
#    'vj siddhu vlogs',
#    'cooking vlog',
#    'vj siddhu cooking vlog',
#    'diwali special'],
#   'Thumbnail': 'https://i.ytimg.com/vi/yKizwXo57UQ/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #funcooking #cookingvlog #diwali #diwalicooking \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-28T10:10:07Z',
#   'Duration': 'PT21M58S',
#   'Views': '2271630',
#   'Likes': '149020',
#   'Comments': '1326',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'd28X__L7RkI',
#   'Title': 'வெண்ட முட்டை செய்யப் போறோம் 🤣👌 | Bali Ep- 12 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'bali vlog',
#    'siddhu bali series',
#    'Siddhu cooking vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/d28X__L7RkI/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #cookingvlog #baliseries #episode12 \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-27T04:30:07Z',
#   'Duration': 'PT20M52S',
#   'Views': '2574919',
#   'Likes': '157833',
#   'Comments': '1362',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'pVb_AMqoqaU',
#   'Title': 'எப்படிப்பட்ட வரிகள் 🤕 | Bali Ep- 11 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'Bali Vlogs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/pVb_AMqoqaU/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #baliseries #episode11\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-25T09:30:08Z',
#   'Duration': 'PT16M26S',
#   'Views': '2124766',
#   'Likes': '154624',
#   'Comments': '1257',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'zXzMYAzdjkI',
#   'Title': 'இவன் திருந்த மாட்டான் போலையே😱🤔 | Bali Ep- 10 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'Bali Vlogs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/zXzMYAzdjkI/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #baliseries #episode10\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-23T10:00:07Z',
#   'Duration': 'PT20M3S',
#   'Views': '2152002',
#   'Likes': '145105',
#   'Comments': '1144',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': '3YVsmHCtQX0',
#   'Title': 'Diwali Shopping Starts🤩🛍 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'siddhu and harshath',
#    'siddhu recent video',
#    'siddhu video',
#    'siddhu interview',
#    'vj siddhu vlogs latest vlog',
#    'saravana stores',
#    'vj sidhu saravana stores vlog',
#    'siddhu and harshath vlog',
#    'saravana stores vlog',
#    'vj siddhu new video'],
#   'Thumbnail': 'https://i.ytimg.com/vi/3YVsmHCtQX0/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #saravanastores #diwalishopping #shoppingvlog \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-21T10:00:07Z',
#   'Duration': 'PT28M40S',
#   'Views': '2923572',
#   'Likes': '191389',
#   'Comments': '2919',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'gxBURlXYkUw',
#   'Title': 'விளையாட்டு விபரீதம் ஆகிருச்சே😰| Bali Ep- 9 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'Bali Vlogs',
#    'bali episodee 9'],
#   'Thumbnail': 'https://i.ytimg.com/vi/gxBURlXYkUw/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n#vjsiddhuvlogs #funvlogs #baliseries #ouija #episode9 \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-20T04:30:07Z',
#   'Duration': 'PT27M23S',
#   'Views': '2495031',
#   'Likes': '164694',
#   'Comments': '2710',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'bbEnUUqYRQY',
#   'Title': 'இதுக்கு அப்றம் நிம்மதி போச்சு🤕🤧 | Bali Ep- 8 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'bali episode 8',
#    'Bali Vlogs'],
#   'Thumbnail': 'https://i.ytimg.com/vi/bbEnUUqYRQY/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #harshathkhan #episode8\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-18T09:30:07Z',
#   'Duration': 'PT15M57S',
#   'Views': '2289308',
#   'Likes': '167639',
#   'Comments': '1240',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'lAVwlqGC2Do',
#   'Title': 'அவன் கிடக்குறான் இது நல்லாருக்கு🤩🥳 | Bali Ep- 7 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'bali trip episode 7'],
#   'Thumbnail': 'https://i.ytimg.com/vi/lAVwlqGC2Do/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #shoppingvlog #kutabeach #episode7\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-16T09:30:07Z',
#   'Duration': 'PT19M22S',
#   'Views': '2225554',
#   'Likes': '145405',
#   'Comments': '1377',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Title': 'Worth Varma Worth-uh 💥🔥| Bali Ep- 6 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video',
#    'atv',
#    'atv bike',
#    'atv bike ride'],
#   'Thumbnail': 'https://i.ytimg.com/vi/h6hVTkLUCf4/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #atv #atvride #episode6 \n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-14T09:30:08Z',
#   'Duration': 'PT13M20S',
#   'Views': '1877879',
#   'Likes': '141113',
#   'Comments': '1054',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Title': 'மீன் கடிச்சா செத்திருவோமா😱| Bali Ep- 5 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'celebrity sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video'],
#   'Thumbnail': 'https://i.ytimg.com/vi/z9rbAGIMXB4/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #episode5 #jeepsafari \n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-13T04:30:29Z',
#   'Duration': 'PT21M29S',
#   'Views': '2003444',
#   'Likes': '134891',
#   'Comments': '1895',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'zmsF_dsHkzM',
#   'Title': 'புலி நடிச்சு இப்பதான் பாக்குறேன்😱🔥| Bali Ep- 4 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'celebrity sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'vj siddhu bali video',
#    'zoo',
#    "asia's largest zoo"],
#   'Thumbnail': 'https://i.ytimg.com/vi/zmsF_dsHkzM/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #zoo #episode4\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-11T09:30:08Z',
#   'Duration': 'PT19M8S',
#   'Views': '2141798',
#   'Likes': '143072',
#   'Comments': '1151',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'V_gtVAbGRkQ',
#   'Title': 'இதெல்லாமாவா சாப்பிடுறாங்க😱🤢 | Bali Ep- 3 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'celebrity sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog',
#    'vj siddhu bali video'],
#   'Thumbnail': 'https://i.ytimg.com/vi/V_gtVAbGRkQ/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #streefood #episode3\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-09T09:30:07Z',
#   'Duration': 'PT18M27S',
#   'Views': '2438826',
#   'Likes': '153295',
#   'Comments': '1581',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'Gt5yZJB1zAQ',
#   'Title': 'போட்டுத் தாக்கிட்டாரு முடியல😫 | Bali Ep- 2 | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'celebrity sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Gt5yZJB1zAQ/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #episode2\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-07T09:30:22Z',
#   'Duration': 'PT16M45S',
#   'Views': '2287388',
#   'Likes': '162392',
#   'Comments': '988',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'KDYog6NeA9o',
#   'Title': 'மாட்டுனாண்டா Celebrity Sathish | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'bali vlogs',
#    'bali series',
#    'vj siddhu vlogs',
#    'vj siddhu vlogs bali series',
#    'vj siddhu vlogs bali vlog',
#    'siddhu balli series',
#    'harshath khan',
#    'sathish',
#    'celebrity sathish',
#    'bali vlog',
#    'siddhu bali series',
#    'siddhu new series vlog'],
#   'Thumbnail': 'https://i.ytimg.com/vi/KDYog6NeA9o/default.jpg',
#   'Description': 'GT Holidays:\nContact GT holidays for Tour Packages all across the globe\nFor more details : https://www.gtholidays.in/\nCall : 9940882200\n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com  \n\n#vjsiddhuvlogs #funvlogs #balivlogs #episode1 \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-06T04:30:18Z',
#   'Duration': 'PT19M11S',
#   'Views': '2677187',
#   'Likes': '198116',
#   'Comments': '4018',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': '7zBQFocSBCA',
#   'Title': 'சாதிக்க பொறந்தவன்டா இந்த Sabbu | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Siddhu latest videos',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'vj siddhu vlogs',
#    'siddhu',
#    'SiddhuVlogs',
#    'Vj siddhu',
#    'games',
#    'siddhu video',
#    'vj siddhu video',
#    'game',
#    'game play',
#    'siddhu vlogs game',
#    'funny vlogs',
#    'funny game vlogs',
#    'siddhu game',
#    'rummy game',
#    'siddhu rummy game'],
#   'Thumbnail': 'https://i.ytimg.com/vi/7zBQFocSBCA/default.jpg',
#   'Description': 'For Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n#vjsiddhuvlogs #funvlogs #rummygame #game\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2024-10-04T09:30:08Z',
#   'Duration': 'PT20M57S',
#   'Views': '2351239',
#   'Likes': '154055',
#   'Comments': '1368',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'Msus5xgBIJU',
#   'Title': 'Chicken Laddu செய்வது எப்படி 🤩🥳 | Fun Cooking With BOYS | Vj Siddhu Vlogs',
#   'Tags': ['Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Siddhu',
#    'Siddhu vlogs',
#    'Siddhu channel',
#    'Vj Siddhu channel',
#    'Vj Siddhu',
#    'Vj Siddhu Vlogs latest',
#    'Vlogs',
#    'Vlog',
#    'fun panrom vlogs',
#    'sidhu vlogs',
#    'siddhu vlogs',
#    'vj siddhu prank',
#    'vj siddhu latest vlog',
#    'vj siddhu latest',
#    'vj siddhu new video',
#    'vj siddhu funny',
#    'vj siddhu harshath khan',
#    'harshath khan',
#    'vj siddhu comedy vlog',
#    'vj siddhu cooking',
#    'vj siddhu vlogs',
#    'cooking vlog',
#    'vj siddhu cooking vlog',
#    'np',
#    'adhirchi arun'],
#   'Thumbnail': 'https://i.ytimg.com/vi/Msus5xgBIJU/default.jpg',
# ...
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'SPyVuauAYrU',
#   'Title': 'நாம் மறந்த 90s Kids விளையாட்டு பொருட்கள் 😍 | Old Memories With Iniyazh 🎉| Vj Siddhu Vlogs',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'fun panrom siddhu vlog',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'vj siddhu new youtube channel',
#    'siddhu',
#    'Vj siddhu',
#    'funpanrom',
#    'vj siddhu fun vlog',
#    'vj sidhu',
#    '90s mystery box',
#    '90s kids games',
#    'playing with daughter',
#    'variety of toys',
#    '90s kids gifts',
#    'fun panrom with siddhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/SPyVuauAYrU/default.jpg',
#   'Description': "For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com\n\n#vjsiddhuvlogs #funvlogs #90severgreen #90skids #90skidssweetmemories #90skidsfavourites \n\nHey guys! Join me for a nostalgic trip down memory lane as we embark on an exciting unboxing segment!\n\n In this video, I'll be unwrapping and rediscovering the beloved games every 90s kid played during their magical childhood days. \n\nGet ready to relive the joy and excitement as we uncover the treasures inside each gift box. Let's dive deeply into the past and reconnect with the games that shaped our fondest memories!\n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies",
#   'Published_Date': '2023-07-05T09:45:08Z',
#   'Duration': 'PT18M24S',
#   'Views': '728891',
#   'Likes': '35936',
#   'Comments': '0',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'UKbg8CEEmmA',
#   'Title': 'Vijay Antony Sir வீட்டுல நடந்த சம்பவம் 💔| Delivery Boy Emotional | Vj Siddhu Vlogs',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'funparom siddhu new video',
#    'fun panrom siddhu vlog',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'vj siddhu new youtube channel',
#    'siddhu',
#    'Vj siddhu',
#    'vj siddhu prank',
#    'delivery boy prank',
#    'fun panrom siddhu prank',
#    'funpanrom',
#    'swiggy delivery boy prank',
#    'vj siddhu swiggy delivery prank'],
#   'Thumbnail': 'https://i.ytimg.com/vi/UKbg8CEEmmA/default.jpg',
#   'Description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com\n\nHello guys! Today I wanted to do something new for the YT family, unlike other food vlogs. \n\nThis vlog intends to understand the life of people in the food delivery business, eligibility to become a delivery guy in Swiggy, and more.\n\nYou catch my day out with a Swiggy delivery guy Askar in this vlog. After a chit-chat over a piping hot chai, he joined me on a car ride and conversation\n\n\n#vjsiddhuvlogs #funvlogs #funpanromsiddhu #fooddelivery #respectall  \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2023-06-30T09:45:07Z',
#   'Duration': 'PT10M1S',
#   'Views': '669003',
#   'Likes': '33860',
#   'Comments': '332',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'AJ4J6soRGQg',
#   'Title': 'Swiggy-ல இருந்தா இவ்ளோ சம்பளமா 🤑  | One Day Delivery Partner | Vj Siddhu',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'funparom siddhu new video',
#    'fun panrom siddhu vlog',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'vj siddhu new youtube channel',
#    'siddhu',
#    'Vj siddhu',
#    'vj siddhu prank',
#    'delivery boy prank',
#    'fun panrom siddhu prank',
#    'funpanrom',
#    'swiggy delivery boy prank',
#    'vj siddhu swiggy delivery prank'],
#   'Thumbnail': 'https://i.ytimg.com/vi/AJ4J6soRGQg/default.jpg',
#   'Description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\nHello guys! Today I wanted to do something new for the YT family, unlike other food vlogs. \n\nThis vlog intends to understand the life of people in the food delivery business, eligibility to become a delivery guy in Swiggy, and more.\n\nYou catch my day out with a Swiggy delivery guy Askar in this vlog. After a chit-chat over a piping hot chai, he joined me on a car ride and conversation. \n\n#vjsiddhu #vjsiddhuvlogs #funpanromsiddhu #fooddelivery #respectall \n\n___________________________________\n\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\nInstagram :- https://www.instagram.com/vjsiddhu_official/?igshid=OGQ5ZDc2ODk2ZA%3D%3D\nPage Instagram :- https://www.instagram.com/vjsiddhu_vlogs/?igshid=MmIzYWVlNDQ5Yg%3D%3D\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies',
#   'Published_Date': '2023-06-28T11:30:11Z',
#   'Duration': 'PT21M32S',
#   'Views': '1213341',
#   'Likes': '49077',
#   'Comments': '440',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'FBZFmBcm-lw',
#   'Title': 'குடிமகன்கள் Health- ம் முக்கியம் தான்😍🎉 |  Jil Jil Bar Food Review💥 | Vj Siddhu',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'funparom siddhu new video',
#    'fun panrom siddhu vlog',
#    'party',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'vj siddhu new youtube channel',
#    'Vj siddhu party',
#    'siddhu',
#    'Tasmac',
#    'Prabha wines',
#    'Tasmac Food Review',
#    'food Review in tasmac',
#    'Vj siddhu Food Vlog',
#    'Vj siddhu tasmac video',
#    'Vj siddhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/FBZFmBcm-lw/default.jpg',
#   'Description': "For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\nHello guys! We are at Jil Jil Bar, which is not as cool as the name but is very famous. \n\nJoin us for a food adventure as we explore this place's various dishes that attract people.\n\nThis video brings my food-tasting moment reviewing one by one. Watch the latest video to know about our experience and the place! \n\n#vjsiddhu #vlog #vjsiddhuvlogs #foodreview #sidedish #funpanromsiddhu \n\n------------------------------------------------------------------------------------------------------------------------------------------------------\nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n\nInstagram :- https://instagram.com/vjsiddhu_official?igshid=OGQ5ZDc2ODk2ZA== \n\nInstagram :- https://instagram.com/vjsiddhu_vlogs?igshid=MmIzYWVlNDQ5Yg==\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies",
#   'Published_Date': '2023-06-26T10:30:10Z',
#   'Duration': 'PT14M41S',
#   'Views': '855337',
#   'Likes': '43429',
#   'Comments': '457',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': '7f8GkhCakxs',
#   'Title': 'Tasmac-ல இவ்ளோ Variety Side Dish-ஆ 😋💥என்னா Tasteu🎉| Vj Siddhu',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'funparom siddhu new video',
#    'fun panrom siddhu vlog',
#    'party',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'vj siddhu new youtube channel',
#    'Vj siddhu party',
#    'siddhu',
#    'Tasmac',
#    'Prabha wines',
#    'Tasmac Food Review',
#    'food Review in tasmac',
#    'Vj siddhu Food Vlog',
#    'Vj siddhu tasmac video',
#    'Vj siddhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/7f8GkhCakxs/default.jpg',
#   'Description': "For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\nHey there, folks! Brace yourselves for a mind-blowing revelation. Believe it or not, tucked away in the bustling city of Chennai lies a magical place called TASMAC, where the drinks are just the beginning. \n\nIn this vlog, we're not focusing on the drinks but instead on the mouthwatering stars of the show: boneless chicken 65, the majestic Maharaja, and the fiery pepper Mushroom.\n\nGet ready to have your taste buds sent on a wild, flavour-packed adventure with their phenomenal side dishes! \n\n #vjsiddhu #vjsiddhu #funpanromsiddhu #vlog #foodvlog #foodreview \n____________________________________________________________ \nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n\nInstagram :- https://instagram.com/vjsiddhu_official?igshid=OGQ5ZDc2ODk2ZA== \n\nInstagram :- https://instagram.com/vjsiddhu_vlogs?igshid=MmIzYWVlNDQ5Yg==\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies",
#   'Published_Date': '2023-06-23T09:40:08Z',
#   'Duration': 'PT9M50S',
#   'Views': '673275',
#   'Likes': '33090',
#   'Comments': '369',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'N6hC1j2p8HI',
#   'Title': 'இது சாதாரண நாய் இல்ல Circus நாய் 😂 | A Day With Chottu Dog | Part 2 | Vj Siddhu',
#   'Tags': ['vj siddhu',
#    'Vjsiddhu',
#    'vj siddhu vlogs',
#    'Funpanrom',
#    'funparom siddhu vlogs',
#    'funpanrom siddhu',
#    'blacksheep siddhu comedy',
#    'vj siddhu vlog channel',
#    'vj siddhu new video',
#    'funparom siddhu new video',
#    'dog feeding',
#    'day with dog',
#    'day with dog vlog',
#    'pet dog',
#    'fun panrom siddhu vlog',
#    'Night party',
#    'party',
#    'party with dog',
#    'Vj siddhu funny',
#    'fun parom siddhu comedy',
#    'vj siddhu youtube channel',
#    'vj siddhu comedy',
#    'tamil dog comedy',
#    'vj siddhu new youtube channel',
#    'Vj siddhu party',
#    'Dog attrocities',
#    'siddhu'],
#   'Thumbnail': 'https://i.ytimg.com/vi/N6hC1j2p8HI/default.jpg',
#   'Description': "For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com\n\nCheck out Previous Video :- Part 1 :-https://youtu.be/2KtPwmjqtBk\n\nHello guys! Join me for a day at home with my adorable dog, Chottu. As soon as the sun peeks through the curtains, Chottu's wagging tail and joyful barks greet me, signalling the start of our day together.\n\nWatch the latest video to learn about dog food, eating habits, and how I bond with my fluffy friend. \n\nSubscribe to my channel and get more videos that give a perfect sneak peek of my life.\n\n\n#vjsiddhu #vjsiddhu #funpanromsiddhu #dog #vlog \n____________________________________________________________ \nFollow My Social Media Pages \n\nFacebook :- https://www.facebook.com/siddhuvideos?mibextid=LQQJ4d\n\nInstagram :- https://instagram.com/vjsiddhu_official?igshid=OGQ5ZDc2ODk2ZA== \n\nInstagram :- https://instagram.com/vjsiddhu_vlogs?igshid=MmIzYWVlNDQ5Yg==\n\n___________________________________\n\nIn Association with DIVO - Digital Partner\nWebsite - http://web.divo.in/\nInstagram - https://www.instagram.com/divomovies/\nFacebook - http://www.facebook.com/divomovies\nTwitter - https://twitter.com/divomovies",
#   'Published_Date': '2023-06-20T10:30:08Z',
#   'Duration': 'PT12M26S',
#   'Views': '1773699',
#   'Likes': '81957',
#   'Comments': '530',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': '2KtPwmjqtBk',
#   'Title': 'எப்படி வந்து சிக்கி இருக்கேன் பாத்தியா 😒  | Vj Siddhu Vlogs',
#   'Tags': ['vj siddhu',
#    'fun panrom',
#    'vj siddhu prank',
#    'vj siddhu fun panrom',
#    'vj siddhu fun panrom vlogs',
#    'vj siddhu vlog',
#    'vj siddhu bloopers',
#    'vj siddhu wife',
#    'Vj Siddhu Vlogs',
#    'Vj Siddhu Vlogs Youtube channel',
#    'Vj Siddhu Youtube channel',
#    'Vj Siddhu new Youtube channel',
#    'Blacksheep Siddhu Youtube channel',
#    'fun panrom Siddhu Youtube channel',
#    'Blacksheep fun panrom Siddhu Youtube channel',
#    'Vj Siddhu Vlogs channel',
#    'Vj Siddhu new video',
#    'Vi sidhu vlogs',
#    'Blacksheep sidhu channel',
#    'vj siddhu new video'],
#   'Thumbnail': 'https://i.ytimg.com/vi/2KtPwmjqtBk/default.jpg',
#   'Description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\nCheck Out Part 2 - https://youtu.be/N6hC1j2p8HI\n\n#VjSiddhuVlogs #VjSiddhu #SidhhuVlogs\n\nWelcome to Vj Sidhhu Vlogs. \nSubscribe at https://youtube.com/@UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Published_Date': '2023-06-18T10:00:14Z',
#   'Duration': 'PT12M59S',
#   'Views': '3537344',
#   'Likes': '113117',
#   'Comments': '825',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'true'},
#  {'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Video_Id': 'OkuCdKIYzX0',
#   'Title': 'நான் வந்துட்டேன் சொல்லு திரும்ப வந்துட்டேனு சொல்லு..! | New Channel | Vj Siddhu Vlogs',
#   'Tags': ['Vj siddhu vlogs',
#    'Vj siddhu',
#    'sidhhu vlogs',
#    'vj siddhu new channel',
#    'siddhu new vlog',
#    'vj siddhu vlogs',
#    'blacksheep sidhhu vlogs',
#    'fun pandrom vlogs',
#    'fun panrom vlogs',
#    'vj sidhhu new vlog',
#    'vj siddhu channel',
#    'Siddhu new channel'],
#   'Thumbnail': 'https://i.ytimg.com/vi/OkuCdKIYzX0/default.jpg',
#   'Description': 'For inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n\n  #VjSiddhuVlogs #VjSiddhu #SidhhuVlogs\n\n\nWelcome to Vj Sidhhu Vlogs. \nSubscribe at https://youtube.com/@VjSiddhuVlog',
#   'Published_Date': '2023-06-17T11:02:30Z',
#   'Duration': 'PT1M5S',
#   'Views': '863195',
#   'Likes': '70255',
#   'Comments': '413',
#   'Favorite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %% [markdown]
# ##### COMMENT INFORMATION

# %%
#get comment information
def get_comment_info(video_ids):
    Comment_data=[]
    try:
        for video_id in video_ids:
            request=youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response=request.execute()

            for item in response['items']:
                data=dict(Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                
                Comment_data.append(data)
                
    except:
        pass
    return Comment_data

# %%
comment_information = get_comment_info(video_ids)

# %%
comment_information
# Out:
# [{'Comment_Id': 'UgxZO5YOe3R02D3cQUh4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Real meesaya murukku moment 🔥🔥🔥🔥🔥 <a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=681">11:21</a>',
#   'Comment_Author': '@JOSIMANOHARVS',
#   'Comment_Published': '2024-11-16T04:27:41Z'},
#  {'Comment_Id': 'UgxSY1cTosmjhQtWMAV4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'brother at batu caves got Hanuman temple also y anny vloger never show or talk about Hanuman temple come see Murugan only',
#   'Comment_Author': '@suganthanloganathen7329',
#   'Comment_Published': '2024-11-16T04:13:22Z'},
#  {'Comment_Id': 'Ugz9XvUfL8JNN-eH0_14AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'My hometown',
#   'Comment_Author': '@thayalnibalachandran6636',
#   'Comment_Published': '2024-11-16T04:11:40Z'},
#  {'Comment_Id': 'UgwirfePUSraZnpUOVp4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Nxt virunthu Thoothukudi',
#   'Comment_Author': '@Beeechoooguys',
#   'Comment_Published': '2024-11-16T04:10:37Z'},
#  {'Comment_Id': 'UgyH2lrMA_SCFbvyd6J4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=400">6:40</a>  universal truth 🤣🤣🤣',
#   'Comment_Author': '@Beeechoooguys',
#   'Comment_Published': '2024-11-16T04:09:36Z'},
#  {'Comment_Id': 'UgwYWLNPyeDpJuTA1Ld4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=313">5:13</a> murugaaa 😫❤️',
#   'Comment_Author': '@Beeechoooguys',
#   'Comment_Published': '2024-11-16T04:07:45Z'},
#  {'Comment_Id': 'UgyF7NLBLrhWBhG-0jx4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'ரொம்ப நாள் ஆசை அண்ணா ❤❤❤❤,🙏🙏🙏🙏🙏🙏🙏',
#   'Comment_Author': '@subasuba7753',
#   'Comment_Published': '2024-11-16T04:00:47Z'},
#  {'Comment_Id': 'UgyNWsEj8UMs4GTfkwd4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Ennaku romba aasai malasia poganumnu❤',
#   'Comment_Author': '@HarinivasHarinivas-st2ze',
#   'Comment_Published': '2024-11-16T03:47:01Z'},
#  {'Comment_Id': 'UgzM29_cew9nymvNhwN4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '🦚🦚🦚வெற்றிவேல் முருகனுக்கு அரோகரா🦚🦚🦚',
#   'Comment_Author': '@MaheshKumar-tj4xr',
#   'Comment_Published': '2024-11-16T03:28:32Z'},
#  {'Comment_Id': 'Ugx3Mno7YafAd5HY89B4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Siddhu na covai Vellingiri Malai oru vlog Podunga....kandipa neraya fun irukum',
#   'Comment_Author': '@meow_dk',
#   'Comment_Published': '2024-11-16T03:27:09Z'},
#  {'Comment_Id': 'Ugw4nF71DgEvboLVrL94AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Vj... அண்ணா 🎉💙🫶.. பாண்டிச்சேரி எப்போ வரிங்க 😖😖😞😞😞',
#   'Comment_Author': '@padminisanthosh4786',
#   'Comment_Published': '2024-11-16T03:22:24Z'},
#  {'Comment_Id': 'UgyhW_1bae5qHUqG5RN4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Anna sabarimalai ku oru thadava pongana please',
#   'Comment_Author': '@Aathisanthuru',
#   'Comment_Published': '2024-11-16T03:02:05Z'},
#  {'Comment_Id': 'UgwICXkH5tpPSW8JWIx4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Appadah Naa kooda enakku mattum thaa padi yerumbothu moochi vaanguthunnu nenacha 😅',
#   'Comment_Author': '@SURYA155CC',
#   'Comment_Published': '2024-11-16T03:01:52Z'},
#  {'Comment_Id': 'UgxebremP48qU6IYpL94AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Lord murugan ~♥~',
#   'Comment_Author': '@warilingesh6327',
#   'Comment_Published': '2024-11-16T02:50:35Z'},
#  {'Comment_Id': 'UgxFWUyblYgWkcUH-SJ4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'camera work 👌👌',
#   'Comment_Author': '@rengapradeep',
#   'Comment_Published': '2024-11-16T02:45:33Z'},
#  {'Comment_Id': 'UgzXXJF2NMR5dbHiQb14AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Vjsidhu Anna Coimbatore Othimalai Vanga 1800 Steps Earuvom 🙏😍❤\u200d🩹',
#   'Comment_Author': '@BTSPurpleWorld13',
#   'Comment_Published': '2024-11-16T02:44:44Z'},
#  {'Comment_Id': 'Ugy7zWUCFZwEuUF-cvR4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=610">10:10</a> மாமா ராமர் அவர்களே ❤',
#   'Comment_Author': '@ajithkumar8707',
#   'Comment_Published': '2024-11-16T02:30:07Z'},
#  {'Comment_Id': 'UgwwFv4N0VQ9pZ-EPDx4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '😂😊',
#   'Comment_Author': '@lakshmikitchen1051',
#   'Comment_Published': '2024-11-16T02:27:14Z'},
#  {'Comment_Id': 'UgwFUaEJ8E49mmBPwTh4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Kl madhum than illa Anne come to Penang',
#   'Comment_Author': '@VeeraTamil-js1nx',
#   'Comment_Published': '2024-11-16T02:25:34Z'},
#  {'Comment_Id': 'Ugw9TcxJLZiMN7Nt1KN4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Sri Lanka Murugan kovil ponga anna',
#   'Comment_Author': '@VinotjVinoth',
#   'Comment_Published': '2024-11-16T02:17:33Z'},
#  {'Comment_Id': 'Ugw0T2F1WxdxcY0lBPJ4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=401">6:41</a> Valli avana po sollu adichuduvan avana..😂😂 Sheriff bro superrrr.. 😅',
#   'Comment_Author': '@CommonCulprit',
#   'Comment_Published': '2024-11-16T02:16:58Z'},
#  {'Comment_Id': 'Ugwd2vO0ui-4ODGYPXJ4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'அடுத்த விருந்து சேலம்🎉🎉🎉🎉❤❤😊',
#   'Comment_Author': '@DkDhileep',
#   'Comment_Published': '2024-11-16T02:12:23Z'},
#  {'Comment_Id': 'UgxDd82MCuQtZfgH8594AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Ninga pora ooruku ellam nangale pona mathuri irukku ❤❤❤❤',
#   'Comment_Author': '@Mp_offical_',
#   'Comment_Published': '2024-11-16T02:10:17Z'},
#  {'Comment_Id': 'UgwK3yH6gMekz0fqmIt4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Bro romba devotionala 😢iruku bro comeback to fun bró please 🎉',
#   'Comment_Author': '@RevoltMansavage726',
#   'Comment_Published': '2024-11-16T01:56:58Z'},
#  {'Comment_Id': 'UgzZhlbsfw2nsvzYrx54AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=680">11:20</a> bad girl mass ini mass cute 😅😂❤',
#   'Comment_Author': '@RamanSanthosh187',
#   'Comment_Published': '2024-11-16T01:12:06Z'},
#  {'Comment_Id': 'Ugwp91XSG9Y-EE5Hj654AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'டேய் இது கொஞ்சம் புதுசா இருக்கு ஆலயத்தில் செருப்பா 😢',
#   'Comment_Author': '@Kokul-r7o',
#   'Comment_Published': '2024-11-16T01:01:33Z'},
#  {'Comment_Id': 'UgwoN5YKXNW2JNUtikF4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=dEyhsXExCQ4&amp;t=61">1:01</a>  முருகா✨✨😊',
#   'Comment_Author': '@RamanSanthosh187',
#   'Comment_Published': '2024-11-16T00:59:41Z'},
#  {'Comment_Id': 'Ugz1ziebhXc5a-rdl8R4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Anna🙏🙇\u200d♂Kovil padikatu matum 272 illa unga vlog kuda 272 tha anna 😍😍',
#   'Comment_Author': '@vigneshwaran2658',
#   'Comment_Published': '2024-11-15T23:22:24Z'},
#  {'Comment_Id': 'UgzDr0ijlGw7cSMkRp54AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Anna kalugu Malai vaga naa❤',
#   'Comment_Author': '@loguuma7855',
#   'Comment_Published': '2024-11-15T23:05:58Z'},
#  {'Comment_Id': 'UgyIMir1F4U7Qj5M9qB4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '❤முருகா❤',
#   'Comment_Author': '@Jegadeeshms1998-zh4dc',
#   'Comment_Published': '2024-11-15T22:12:13Z'},
#  {'Comment_Id': 'UgxbU1HSyD3kpVmU9l94AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Aprm yen Mairu ku bro english medium join Pannu vachuga bro 😮',
#   'Comment_Author': '@PurusoThaman-n8k',
#   'Comment_Published': '2024-11-15T22:10:55Z'},
#  {'Comment_Id': 'UgzoAMOSf7LPpz-E2S94AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Nenga sammy kumbadurathu thappu anna... Nenga romba murugan pakththan nu therium athunalaa solra anna... Sammy nenga kumbuduraa style thappu anna',
#   'Comment_Author': '@ManiVel-q5t',
#   'Comment_Published': '2024-11-15T20:34:31Z'},
#  {'Comment_Id': 'UgwNrSDpHpDFS0Tn1VF4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'ஓம் முருகா போற்றி🤲🙏🦚🦚<br>Thanks ❤',
#   'Comment_Author': '@ammutharmalingam9125',
#   'Comment_Published': '2024-11-15T20:30:18Z'},
#  {'Comment_Id': 'UgyIoVSe1nCritskO1Z4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'I love sherrif here, some other religion people neglect to do this, inspite he doing this 🎉',
#   'Comment_Author': '@manoharan2188',
#   'Comment_Published': '2024-11-15T20:10:05Z'},
#  {'Comment_Id': 'Ugxe-9jqkp_MQd_gb1V4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Malaysia murugan dharasanam ku nandri anna... Vetrivel murugan ku arogarah.🙏🙏👋',
#   'Comment_Author': '@kalamhs6869',
#   'Comment_Published': '2024-11-15T20:06:46Z'},
#  {'Comment_Id': 'UgwNmKjwbLkOm8obmoV4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Osam anna tq so much',
#   'Comment_Author': '@manikantag5046',
#   'Comment_Published': '2024-11-15T20:00:56Z'},
#  {'Comment_Id': 'Ugw1V24RUhEJJorQrbx4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '272steps and vlog no:272 super anna ....',
#   'Comment_Author': '@vinothvinoth4744',
#   'Comment_Published': '2024-11-15T20:00:43Z'},
#  {'Comment_Id': 'Ugy3s3jdAFhMxV5MMmB4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@stephenroy7669',
#   'Comment_Published': '2024-11-15T19:51:11Z'},
#  {'Comment_Id': 'Ugy5EIQjZdEh2sV7wJh4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'எங்கும் என்னப்பன் முருகன் ஆட்சி, காண்பதற்கு கண்கொள்ளா காட்சி 👌🙏🙏🙏🙏🙏🙏🙏🙏',
#   'Comment_Author': '@sachinsaravanan4040',
#   'Comment_Published': '2024-11-15T19:38:31Z'},
#  {'Comment_Id': 'Ugx5OmU758PDKUYMTXl4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Super anna feeling good',
#   'Comment_Author': '@sathyababusathyababu1846',
#   'Comment_Published': '2024-11-15T19:36:17Z'},
#  {'Comment_Id': 'UgyFaII7HocwxQdEqCp4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Anni voice ipo dha kekurom😂',
#   'Comment_Author': '@startthe-game',
#   'Comment_Published': '2024-11-15T19:35:48Z'},
#  {'Comment_Id': 'UgwUrq7DFD_tn5sb5aZ4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Bad dhan gethuuuuu …..🤙🏻',
#   'Comment_Author': '@ahmedriyaskaan3494',
#   'Comment_Published': '2024-11-15T19:01:54Z'},
#  {'Comment_Id': 'UgzqSAkHkcBMrlkiwtV4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Anna drone pilot ku vacancy irutha soluga na vanthuren professional na',
#   'Comment_Author': '@AlphaMomentz-gv4ib',
#   'Comment_Published': '2024-11-15T18:57:13Z'},
#  {'Comment_Id': 'UgyHTbbOCWyTUmD8gzB4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '\U0001faf8\U0001faf7💠🕉️',
#   'Comment_Author': '@DivyaPriya-eq7rt',
#   'Comment_Published': '2024-11-15T18:53:51Z'},
#  {'Comment_Id': 'UgzYAxtnavGpTghlYvR4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Waiting for Madurai virundhu❤',
#   'Comment_Author': '@rishnitha1038',
#   'Comment_Published': '2024-11-15T18:41:31Z'},
#  {'Comment_Id': 'UgwAawXc1UWIhVIB3Hp4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Nandri bro Malaysia murugan temple kamichaduku',
#   'Comment_Author': '@dilibanthirumurthi7317',
#   'Comment_Published': '2024-11-15T18:24:32Z'},
#  {'Comment_Id': 'UgxrZSuNZhUCbpRKG_h4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Bro 3.59 subscribes 3.6 subscribe',
#   'Comment_Author': '@varnavim.m5534',
#   'Comment_Published': '2024-11-15T18:21:01Z'},
#  {'Comment_Id': 'Ugwuhyw2x7IEXng1dpd4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': 'Enna bro subscribe korangi pochu',
#   'Comment_Author': '@varnavim.m5534',
#   'Comment_Published': '2024-11-15T18:19:56Z'},
#  {'Comment_Id': 'Ugw5pOC_ADxff0fImQp4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@JsjkKdkx',
#   'Comment_Published': '2024-11-15T18:18:54Z'},
#  {'Comment_Id': 'UgwUBRPE0AbaMQ-fzsh4AaABAg',
#   'Video_Id': 'dEyhsXExCQ4',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@heerasunil99',
#   'Comment_Published': '2024-11-15T18:17:10Z'},
#  {'Comment_Id': 'Ugz8ep8zZEm01old84V4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Nalaiku mrng exam night 1 o clock vlog parthutu irukan 😂😂😂😂',
#   'Comment_Author': '@NaveenK-k2o',
#   'Comment_Published': '2024-11-15T19:50:12Z'},
#  {'Comment_Id': 'UgyL2LjHDWuDGMAFMC94AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Jimmuku jimmuku song Harsarth sing panadhu??',
#   'Comment_Author': '@Phonefunny2023',
#   'Comment_Published': '2024-11-15T18:45:25Z'},
#  {'Comment_Id': 'UgwptwL4ulewOAgHyGV4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@anjalidev8908',
#   'Comment_Published': '2024-11-15T16:23:54Z'},
#  {'Comment_Id': 'UgwlHMD3lqMCrAM5JJx4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'என்ன ஒரு கேம்...😮 நெல்லை மாவட்ட VJ சித்து ரசிகர் மன்ற நிர்வாகி ரோல்ஸ் ராம்.',
#   'Comment_Author': '@user-rollsram07rolex',
#   'Comment_Published': '2024-11-15T15:35:35Z'},
#  {'Comment_Id': 'Ugw9OQNm9kJFlfH08Ex4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤',
#   'Comment_Author': '@RjRaja-b2q',
#   'Comment_Published': '2024-11-15T15:31:43Z'},
#  {'Comment_Id': 'UgzZ8cYxccrB9o_DZpx4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '(\\_/)<br>(•.•)<br>&gt;❤',
#   'Comment_Author': '@J.GowthamDharshan',
#   'Comment_Published': '2024-11-15T13:55:57Z'},
#  {'Comment_Id': 'Ugy4s4-DVRkZ4F3AhX14AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Appada cringe mudya pothu😢😂🎉',
#   'Comment_Author': '@mohanviews',
#   'Comment_Published': '2024-11-15T11:54:30Z'},
#  {'Comment_Id': 'UgzPXrDMda4I9sV03jJ4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '😍😍🔥🔥😍😍',
#   'Comment_Author': '@sivaraman9760',
#   'Comment_Published': '2024-11-15T10:32:25Z'},
#  {'Comment_Id': 'UgyaDA5jGJqt_vJoZot4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Nice super Anna 🫶🫶🫶🫶🫶❤❤❤',
#   'Comment_Author': '@gopikagodiarasu',
#   'Comment_Published': '2024-11-15T10:17:56Z'},
#  {'Comment_Id': 'UgzqJSPMmd9qoVyf3j54AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Its my birthday but 0 likes',
#   'Comment_Author': '@MhxdNowfal',
#   'Comment_Published': '2024-11-15T05:30:49Z'},
#  {'Comment_Id': 'UgyiQ-i8o739To5ftvR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Aduta vadi kandipa marupadiyum Malaysia ku vange please 😢',
#   'Comment_Author': '@amarawathiSubramaniam',
#   'Comment_Published': '2024-11-15T04:37:31Z'},
#  {'Comment_Id': 'UgwS2z6EZrpIc_P_mfh4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Hi Anna I&#39;m from Malaysia unge virundhuku anal varamudiyale naa unge big fan 😢',
#   'Comment_Author': '@amarawathiSubramaniam',
#   'Comment_Published': '2024-11-15T04:36:05Z'},
#  {'Comment_Id': 'UgwdgPsMox0aGgr41ZV4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Congratulations anna 👏🏻🎇❤',
#   'Comment_Author': '@mithra_editz',
#   'Comment_Published': '2024-11-15T03:35:20Z'},
#  {'Comment_Id': 'Ugzv1BPz8rnVH5twedR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@PeriyannanpillaiRajeethan',
#   'Comment_Published': '2024-11-15T03:20:26Z'},
#  {'Comment_Id': 'Ugw10cd834c8y7Tpk694AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'அண்ணா ஏன்னு தெரியல, நாம கொஞ்சம் down ஆகுற மாதிரி தோனுது கொஞ்சம் பாத்துக்கோங்க',
#   'Comment_Author': '@vijayasaha.b9815',
#   'Comment_Published': '2024-11-14T19:22:27Z'},
#  {'Comment_Id': 'Ugy524-aMh-Ikri26xl4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '🔥🔥🔥',
#   'Comment_Author': '@tharanyaathiletchumi9946',
#   'Comment_Published': '2024-11-14T19:22:08Z'},
#  {'Comment_Id': 'UgwKZiUB6L_0HP1IQep4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Muruga',
#   'Comment_Author': '@jeevankulandhairaj4064',
#   'Comment_Published': '2024-11-14T19:16:09Z'},
#  {'Comment_Id': 'Ugxzl1aR8-LewK3SU354AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤',
#   'Comment_Author': '@gopinathm1853',
#   'Comment_Published': '2024-11-14T18:01:35Z'},
#  {'Comment_Id': 'UgzOXUudi9XVZpSpb5x4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Kumbakonam virundhunadathukana',
#   'Comment_Author': '@Vijayaragavan-pv6fq',
#   'Comment_Published': '2024-11-14T17:54:41Z'},
#  {'Comment_Id': 'Ugx2UHArjzjziFlheVp4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Stress reliver VJ siddhu bro❤❤❤❤❤',
#   'Comment_Author': '@JJshorts1719',
#   'Comment_Published': '2024-11-14T17:35:09Z'},
#  {'Comment_Id': 'UgynOG3y9kQJMF5vudR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Thanks for 285 subscribers 🎉',
#   'Comment_Author': '@ali_edittz7',
#   'Comment_Published': '2024-11-14T17:20:45Z'},
#  {'Comment_Id': 'Ugxw0JH_nNGhA_z418R4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'எங்கடா சூரி',
#   'Comment_Author': '@Karuppa-puchi_13',
#   'Comment_Published': '2024-11-14T16:51:20Z'},
#  {'Comment_Id': 'UgytRLrLzh6XL-0bo0t4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Please come to thanjavur siddhu anna ❤❤❤❤',
#   'Comment_Author': '@praveensrinivasan9578',
#   'Comment_Published': '2024-11-14T16:33:24Z'},
#  {'Comment_Id': 'UgyPgfqc-CAXVrjII5x4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Hi siddhu anna ❤❤❤❤',
#   'Comment_Author': '@praveensrinivasan9578',
#   'Comment_Published': '2024-11-14T16:32:53Z'},
#  {'Comment_Id': 'Ugy8muwM82yevnv0plx4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤',
#   'Comment_Author': '@KisgoeKigroe',
#   'Comment_Published': '2024-11-14T16:27:12Z'},
#  {'Comment_Id': 'UgxbD-R-Szlwu8K4RbF4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '5.07 who is that arun?',
#   'Comment_Author': '@sangavirajendran4314',
#   'Comment_Published': '2024-11-14T16:00:21Z'},
#  {'Comment_Id': 'Ugx-TPBPUqc6kFPnGj94AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '2 mins 😗Ethuku intha kosuru',
#   'Comment_Author': '@A.MonishKumar',
#   'Comment_Published': '2024-11-14T15:12:28Z'},
#  {'Comment_Id': 'UgzRL7r5SqPluzs2Lbt4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤',
#   'Comment_Author': '@prabhuyuvaraj1933',
#   'Comment_Published': '2024-11-14T14:50:03Z'},
#  {'Comment_Id': 'UgwChcQrHgx5hk22Tx94AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Thanks for 30 subscribers',
#   'Comment_Author': '@Optumxsff',
#   'Comment_Published': '2024-11-14T13:27:04Z'},
#  {'Comment_Id': 'UgyY-bqLBj05L-5C8B14AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Anna Kumbakonam virudhu vainga plz',
#   'Comment_Author': '@Shihana-br6ou',
#   'Comment_Published': '2024-11-14T12:43:21Z'},
#  {'Comment_Id': 'UgyCZRU2coMVK7PlVuR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Vera level ponga🎉🎉🎉 last seen mass panitinga🎉🎉❤❤❤',
#   'Comment_Author': '@KeerthanaJeev.j',
#   'Comment_Published': '2024-11-14T12:15:55Z'},
#  {'Comment_Id': 'Ugzb-sl5Yz4qK2F2KzN4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'broo content koonjaam munaadi maaari illaaa bro pathukoongaa',
#   'Comment_Author': '@NithienS',
#   'Comment_Published': '2024-11-14T12:11:04Z'},
#  {'Comment_Id': 'Ugzc8sM5VAz9gVv39K94AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=AnZJvhR-TG0&amp;t=280">4:40</a> HCD💯⚡',
#   'Comment_Author': '@RamanSanthosh187',
#   'Comment_Published': '2024-11-14T11:54:59Z'},
#  {'Comment_Id': 'UgzqSz6NOSH72uMj5KR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '🤣🤣🤣',
#   'Comment_Author': '@AbikuttyNatchiyar',
#   'Comment_Published': '2024-11-14T11:53:59Z'},
#  {'Comment_Id': 'UgxedqaE3kSsmIRubgp4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=AnZJvhR-TG0&amp;t=131">2:11</a> super girls❤',
#   'Comment_Author': '@RamanSanthosh187',
#   'Comment_Published': '2024-11-14T11:51:58Z'},
#  {'Comment_Id': 'UgxuLHNzOc0JuM9o5lV4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=AnZJvhR-TG0&amp;t=392">6:32</a> ithanda frame 💥🔥😎',
#   'Comment_Author': '@praba_pkcreation3353',
#   'Comment_Published': '2024-11-14T11:46:16Z'},
#  {'Comment_Id': 'UgxY6f2NBsRPtmwNuVR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Edipi kalakuraiya nee 🔥❤',
#   'Comment_Author': '@anisha329-d3b',
#   'Comment_Published': '2024-11-14T11:46:03Z'},
#  {'Comment_Id': 'UgxIvf7i7DCZnqCzXal4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '<a href="https://www.youtube.com/shorts/oDFh35Tt0Xs">https://youtube.com/shorts/oDFh35Tt0Xs?si=BTq5fdJfSZx_09SC</a>',
#   'Comment_Author': '@vimalasarathy6249',
#   'Comment_Published': '2024-11-14T11:40:15Z'},
#  {'Comment_Id': 'UgyhF3ViixaJQkR1wBR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Enna bro 6minits lam vedio potrinka.... Sad.. 😢',
#   'Comment_Author': '@ammu1172',
#   'Comment_Published': '2024-11-14T11:23:49Z'},
#  {'Comment_Id': 'Ugyy8d-j6LPdxvFHmeN4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Enna thani kuduchutu vardhukulla episode muduchupochu',
#   'Comment_Author': '@abishekraimand562',
#   'Comment_Published': '2024-11-14T10:16:01Z'},
#  {'Comment_Id': 'UgyfKBQ_J2FvrqAX7ol4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Lastt goosebumps 🥹🥹🥹',
#   'Comment_Author': '@ruthsamlee3634',
#   'Comment_Published': '2024-11-14T09:55:14Z'},
#  {'Comment_Id': 'UgwSCsX1GhIXH6KtVHF4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Super bro all the best',
#   'Comment_Author': '@sheikfareeth241',
#   'Comment_Published': '2024-11-14T09:42:44Z'},
#  {'Comment_Id': 'UgxumlLi4jqiiWsGHcR4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Yen vedio ivlo kutty ha irukku😢... itha paakka evlo wait panrom aana yen ipdi 🥺',
#   'Comment_Author': '@PappuPrakash-c2z',
#   'Comment_Published': '2024-11-14T09:24:27Z'},
#  {'Comment_Id': 'Ugxv5h_KA5xOzAw-ghp4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Bro maka maka song😅',
#   'Comment_Author': '@darkblackandblu5241',
#   'Comment_Published': '2024-11-14T09:15:09Z'},
#  {'Comment_Id': 'Ugy3T7Z3DJcz3LQRs9B4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Enna Athukulle Mudinjiduchi 😢',
#   'Comment_Author': '@LakshmiRekha-d1n',
#   'Comment_Published': '2024-11-14T08:18:38Z'},
#  {'Comment_Id': 'UgzYk_0n-_xkp0Aw3mZ4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'NXT virandhu Bangalore le haa ??',
#   'Comment_Author': '@Sudarshan7vlogsun',
#   'Comment_Published': '2024-11-14T08:01:26Z'},
#  {'Comment_Id': 'Ugwauh0lfvqGKugSmBh4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Happy childrens day minion💔',
#   'Comment_Author': '@sundar_2505',
#   'Comment_Published': '2024-11-14T07:48:11Z'},
#  {'Comment_Id': 'Ugzlfyg23o6_OtJzmDN4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Yowww enna ya...... Edhu',
#   'Comment_Author': '@abiabinesh7548',
#   'Comment_Published': '2024-11-14T07:18:49Z'},
#  {'Comment_Id': 'Ugz3GFe0KL_Mewzn5LF4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': 'Please guys enaku konjam support panuga please 😿',
#   'Comment_Author': '@Mk_gaming__9-x',
#   'Comment_Published': '2024-11-14T07:02:44Z'},
#  {'Comment_Id': 'Ugybs4MZgBQIzpd0M4p4AaABAg',
#   'Video_Id': 'AnZJvhR-TG0',
#   'Comment_Text': '❤❤❤❤❤🔥🔥🔥🔥🔥🔥🔥',
#   'Comment_Author': '@vasumathi7242',
#   'Comment_Published': '2024-11-14T06:59:41Z'},
#  {'Comment_Id': 'Ugz3UYjiaMmx5_-mB_t4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'I show speed legend🐐🗿',
#   'Comment_Author': '@HarishCr7-ov1mb',
#   'Comment_Published': '2024-11-16T03:04:43Z'},
#  {'Comment_Id': 'Ugy9PHqqA9tH4k_hBSJ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=150">2:30</a> mass ga🎉',
#   'Comment_Author': '@Gomathi-x4l',
#   'Comment_Published': '2024-11-16T01:57:25Z'},
#  {'Comment_Id': 'Ugzai6G-MhTBgBUgEK14AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=134">2:14</a> Mee in this situation',
#   'Comment_Author': '@Gomathi-x4l',
#   'Comment_Published': '2024-11-16T01:56:34Z'},
#  {'Comment_Id': 'UgzL7Mm0SMlEeaC2Iwh4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sherif..🔥🔥',
#   'Comment_Author': '@ajeeshahamed4854',
#   'Comment_Published': '2024-11-15T19:01:10Z'},
#  {'Comment_Id': 'UgyGkhQTlZLJxsw7uAh4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '13.36 🥺💯',
#   'Comment_Author': '@ramyasubramanian4786',
#   'Comment_Published': '2024-11-15T17:25:41Z'},
#  {'Comment_Id': 'UgzlkwcNLBzxks-XNGZ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '5.56 waatha 🫠🚶🏻\u200d♂️',
#   'Comment_Author': '@kishorebolt7568',
#   'Comment_Published': '2024-11-15T16:15:45Z'},
#  {'Comment_Id': 'UgzU5wet46rlZtH1e3V4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '5.59 wathaaaaaa 🫠💥',
#   'Comment_Author': '@kishorebolt7568',
#   'Comment_Published': '2024-11-15T16:14:29Z'},
#  {'Comment_Id': 'UgzesBEdpJOTxTlDza54AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sheriff ❤❤❤ masss na',
#   'Comment_Author': '@akcreations7730',
#   'Comment_Published': '2024-11-15T15:24:23Z'},
#  {'Comment_Id': 'UgzZ-Tg7XiX_wveTprt4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Why vignesh shivan is coming',
#   'Comment_Author': '@maharaniramamoorthi5672',
#   'Comment_Published': '2024-11-15T13:19:59Z'},
#  {'Comment_Id': 'Ugyd9r0QYvNrLNnCMvp4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Ishowspeed❤',
#   'Comment_Author': '@jprabhakarsanthanam6186',
#   'Comment_Published': '2024-11-15T13:02:07Z'},
#  {'Comment_Id': 'UgyKwsisPNt9SmJv8Bl4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sheriff 👑 take it man ✨🙌',
#   'Comment_Author': '@tamilmaran22',
#   'Comment_Published': '2024-11-15T11:49:40Z'},
#  {'Comment_Id': 'UgzbmroG_f6dFNsWQLV4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Nov.. Banglore le oru virunnddhu vei naa🥺🥲❤',
#   'Comment_Author': '@kamaleshJoshua',
#   'Comment_Published': '2024-11-15T10:16:02Z'},
#  {'Comment_Id': 'UgxKZjEGMYnFKIkS6b14AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Nnn',
#   'Comment_Author': '@GuruDhevan-r1w',
#   'Comment_Published': '2024-11-15T09:32:44Z'},
#  {'Comment_Id': 'Ugzsy1wcBI8v2XeNPHl4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Dance marana mass🔥❤',
#   'Comment_Author': '@pavithra7104',
#   'Comment_Published': '2024-11-14T20:20:31Z'},
#  {'Comment_Id': 'UgwiEpenN0I-2Lo4iRV4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'சித்து உங்களுக்கு நான் சொல்ல விரும்புகிறது : தம்பி உடையான் படைக்கு அஞ்சான் 🔥',
#   'Comment_Author': '@jinnahmasthan3382',
#   'Comment_Published': '2024-11-14T16:46:26Z'},
#  {'Comment_Id': 'Ugyya00tz-pqC7pADSN4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'மாதா! பிதா! குரு! நல்ல நண்பன்!<br>வாழ்க வளமுடன் Sherif bro ❤',
#   'Comment_Author': '@jinnahmasthan3382',
#   'Comment_Published': '2024-11-14T16:43:20Z'},
#  {'Comment_Id': 'UgyfoVUzWgdfthn8Qu54AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sheriff anna❤❤❤',
#   'Comment_Author': '@meowwfurveen7735',
#   'Comment_Published': '2024-11-14T15:48:33Z'},
#  {'Comment_Id': 'UgyPeEENTNIm1YE_9ox4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sheriff annayyy🎉🎉',
#   'Comment_Author': '@meowwfurveen7735',
#   'Comment_Published': '2024-11-14T15:20:27Z'},
#  {'Comment_Id': 'UgygfTj3e4ne-G69q1h4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'What a laugh riot at the end 😂😂memories',
#   'Comment_Author': '@vishalramadoss668',
#   'Comment_Published': '2024-11-14T10:14:19Z'},
#  {'Comment_Id': 'UgwxeaM46F3Xn74wiwJ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤Super Anna😂',
#   'Comment_Author': '@VickyVicky-q4y',
#   'Comment_Published': '2024-11-14T09:46:51Z'},
#  {'Comment_Id': 'Ugw_QoBk-onLV-YHt4t4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤❤❤❤❤',
#   'Comment_Author': '@celestineliza518',
#   'Comment_Published': '2024-11-14T09:38:32Z'},
#  {'Comment_Id': 'UgzRR4qOQJMELvAxTCN4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=1341">22:21</a>  unknown side of Sherif ❤️\u200d🔥🫂',
#   'Comment_Author': '@villadhivillan9545',
#   'Comment_Published': '2024-11-14T09:08:03Z'},
#  {'Comment_Id': 'UgyPCRhqpDnU43Wob394AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Vera level siddhu na❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@vasumathi7242',
#   'Comment_Published': '2024-11-14T06:52:20Z'},
#  {'Comment_Id': 'Ugyz-eJC78ghF-Yxq-J4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Proud moment for sheriff parents..',
#   'Comment_Author': '@TheEddnback',
#   'Comment_Published': '2024-11-14T04:44:43Z'},
#  {'Comment_Id': 'Ugx8uqGaXQJomHf7xYJ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=1250">20:50</a> that&#39;s why we ❤ vj siddhu vlogs❤❤❤❤',
#   'Comment_Author': '@sks249',
#   'Comment_Published': '2024-11-14T04:13:34Z'},
#  {'Comment_Id': 'Ugy-jfsZZT3PfmC3Hql4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '😂',
#   'Comment_Author': '@Latha-lu9mc',
#   'Comment_Published': '2024-11-14T04:03:43Z'},
#  {'Comment_Id': 'UgxH1POrCg_3zRFG_nR4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤❤❤❤',
#   'Comment_Author': '@nippurifnas7738',
#   'Comment_Published': '2024-11-14T04:00:25Z'},
#  {'Comment_Id': 'UgwT1sYffRIA1KBYlah4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤🎉',
#   'Comment_Author': '@Akhil-390',
#   'Comment_Published': '2024-11-14T03:09:05Z'},
#  {'Comment_Id': 'UgxC6IMxgbS0PEeKhvF4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Ungada vidioes pakkakulla depression ewwalawu irunthalum ungada vidiovala relax ahiruthen',
#   'Comment_Author': '@FaleeldeenFaroskhan-l4n',
#   'Comment_Published': '2024-11-13T21:09:06Z'},
#  {'Comment_Id': 'UgxQUwdW0jdaDm8gYLV4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Iam',
#   'Comment_Author': '@FaleeldeenFaroskhan-l4n',
#   'Comment_Published': '2024-11-13T21:06:40Z'},
#  {'Comment_Id': 'UgxBac14kH4O2cb9Mmd4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Fake claps introduce panama irunga pls.. Ungalodadhu chumma ve organic than.. Thevai ilama fake cheer and claps spoil panudhu 😐',
#   'Comment_Author': '@premm2347',
#   'Comment_Published': '2024-11-13T19:48:38Z'},
#  {'Comment_Id': 'UgzgfjEedlyKaC8QgNt4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Sheriff anna entry Vera level',
#   'Comment_Author': '@Mohamedrazn4987',
#   'Comment_Published': '2024-11-13T19:22:27Z'},
#  {'Comment_Id': 'UgxlrBCR74gsaHahYj14AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Anne Madurai ku epoo varuvigaa anneeeeeee',
#   'Comment_Author': '@vinithvino160',
#   'Comment_Published': '2024-11-13T18:22:26Z'},
#  {'Comment_Id': 'UgxlqlY7BT_pkw6ijUR4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'எந்த விசியம் தமிழ்நாட்டில் நடந்தாலும் டிக் டொக் ல வச்சி தமிழ் நாட்டை அசிங்க அசிங்கமா பேசுறீங்க டிக் டொக் இந்தியா ல இல்லை அது அவங்க பேசுறது நமக்கு தெரியாது ஒவொரு நாளும் தமிழ்நாட்டில் நடக்குறதை வச்சி செய்றாங்க மலேசியா மக்கள் இது நம்ப மக்களுக்கு தெரியாது 😡😡😡😡😡😡',
#   'Comment_Author': '@SUBASHT-q9t',
#   'Comment_Published': '2024-11-13T17:32:29Z'},
#  {'Comment_Id': 'UgxwipzxAgbWvqua_1R4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'தமிழ்நாட்டுக்காரணை பார்த்தால் இவங்களுக்கு பிடிக்காது எங்களின் உணவு முறை வேணும் எங்களின் ஆடை வேணும் எங்களின் தெய்வம் வேணும் எங்க ஊரு ஆக்ட்ரேஸ் வேணும் எங்களின் பண்டிகை வேணும் எங்களின் பழக்க வழக்கம் வேணும் ஆனால் எங்களை பார்த்தால் இவங்களுக்கு ஏலக்காரமா இருக்கு நாங்க சொந்த வீட்டில் இருக்கிறோம் சொந்தமா நிலம் இருக்கு மாமா மச்சான் அங்களி பாங்களி னு சொந்த பந்தம் ஒரு பட்டாலாமே இருக்கு அப்படி மலேசியா காரன் கிட்ட என்னா டா இருக்கு எங்களை உங்க நாட்டுல கேவலப்படுத்துறீங்க..... எங்க நாட்டுல நாங்க யாருக்கும் அடிமை இல்லை நீங்க உங்க நாட்டில் மாலாய்க்காரனுக்கும் சீனாகாரனுக்கும் அடிமையா வாழுரீங்க எங்களுக்கு ஒன்று தேவைப்பட்டால் நடுரோட்டில் இறங்கி போராடுவோம் உங்களால முடியுமா சொல்லுங்க மலேசியா மக்களே???????',
#   'Comment_Author': '@SUBASHT-q9t',
#   'Comment_Published': '2024-11-13T17:29:50Z'},
#  {'Comment_Id': 'UgzIZD9WuR6Tea7V3ad4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'yow nee last ahh sonnadhu ennoda ivlo naal kanavu ya 🫂',
#   'Comment_Author': '@kaatupoochi6189',
#   'Comment_Published': '2024-11-13T17:24:32Z'},
#  {'Comment_Id': 'UgwAO8XoAqcyaRTsoTx4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Copyright 💯',
#   'Comment_Author': '@LEODASSLEODASS000',
#   'Comment_Published': '2024-11-13T16:46:41Z'},
#  {'Comment_Id': 'Ugyg5mDy8gWZ2R_aCsd4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '🫂♥️',
#   'Comment_Author': '@gokulk5813',
#   'Comment_Published': '2024-11-13T16:43:17Z'},
#  {'Comment_Id': 'UgzeliIRJtr__NMxgP54AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=1370">22:50</a> 😂 🧨 ( best memories)🖤',
#   'Comment_Author': '@meowkutty7326',
#   'Comment_Published': '2024-11-13T16:40:43Z'},
#  {'Comment_Id': 'UgyV_q7JBej7QdZQDyl4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤❤❤❤❤❤❤❤❤❤🎉🎉🎉🎉🎉🎉🎉',
#   'Comment_Author': '@mksd8776',
#   'Comment_Published': '2024-11-13T16:26:08Z'},
#  {'Comment_Id': 'Ugwe2CIIuAyNWSijlxZ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=1102">18:22</a>  most beautiful moment 😊😊',
#   'Comment_Author': '@mukishavlogger6113',
#   'Comment_Published': '2024-11-13T16:24:49Z'},
#  {'Comment_Id': 'UgyJW_1Cb7v-GMBAZUF4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Anna Pondicherry eppo na varuvinga 😢😢❤',
#   'Comment_Author': '@_Love.__.beatzz_',
#   'Comment_Published': '2024-11-13T15:44:09Z'},
#  {'Comment_Id': 'UgyJ00vH1W9CJJ2Qa614AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=U6Vzawt5pd8&amp;t=392">6:32</a> goosebumps overload🥵🔥♥️',
#   'Comment_Author': '@saran20044',
#   'Comment_Published': '2024-11-13T15:43:03Z'},
#  {'Comment_Id': 'Ugxlz7ctFMCVrW4SXUp4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '@vjsiddhuvlogs fan from kenya',
#   'Comment_Author': '@gunasekaranmuthusamy4327',
#   'Comment_Published': '2024-11-13T15:31:57Z'},
#  {'Comment_Id': 'UgxDqETpf-ZDzByrF414AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Anna super Nishath fun pandrom compo ini videos vera level irukum bro I am waiting',
#   'Comment_Author': '@muruganm54',
#   'Comment_Published': '2024-11-13T15:26:41Z'},
#  {'Comment_Id': 'UgxHhgnCnOEifLORlyx4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'real OG fun panrom',
#   'Comment_Author': '@devaamuthan3929',
#   'Comment_Published': '2024-11-13T15:06:39Z'},
#  {'Comment_Id': 'Ugz2TORmYqBtCs4cXbZ4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '😆😄😄😄',
#   'Comment_Author': '@ashok6178',
#   'Comment_Published': '2024-11-13T15:02:17Z'},
#  {'Comment_Id': 'Ugz7aavFxJsCFU1hhxV4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@elumalielumali8004',
#   'Comment_Published': '2024-11-13T14:59:07Z'},
#  {'Comment_Id': 'Ugz_tYqoKSTn-zUDjm54AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'நீங்க விரலெவல்னா நான் ரொம்ப ஹாப்பி நா',
#   'Comment_Author': '@sureshajith2205',
#   'Comment_Published': '2024-11-13T14:11:24Z'},
#  {'Comment_Id': 'Ugyd4GZ0W02BatkfzuN4AaABAg',
#   'Video_Id': 'U6Vzawt5pd8',
#   'Comment_Text': 'Atutha Thalapathi  Vj Siddu tha ❤',
#   'Comment_Author': '@G.SYovan-wk8mp',
#   'Comment_Published': '2024-11-13T13:49:58Z'},
#  {'Comment_Id': 'Ugy2cEV7c1dzMsgwz0t4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Kumbakonam',
#   'Comment_Author': '@subramaniyensubbu1669',
#   'Comment_Published': '2024-11-15T17:38:15Z'},
#  {'Comment_Id': 'UgyTwjIJpoCezi8tdp94AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=798">13:18</a> @Parithabangal Sudhakar Bro Spotted 😂',
#   'Comment_Author': '@arunkumarm_',
#   'Comment_Published': '2024-11-15T16:52:04Z'},
#  {'Comment_Id': 'UgzJ-Z5V5ZNEigx7wPN4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '4 million virunthu at trichy anna plssssss',
#   'Comment_Author': '@djworld1997',
#   'Comment_Published': '2024-11-15T13:10:55Z'},
#  {'Comment_Id': 'UgzPFzgtyZBhiJ6LPyJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Next virundhu MADURAI&gt;&gt;&gt;&gt;🙏🏻❤❤',
#   'Comment_Author': '@abishekraj9869',
#   'Comment_Published': '2024-11-15T12:29:49Z'},
#  {'Comment_Id': 'UgztWXf9h1kyeclkBEl4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=498">8:18</a><br> She&#39;s Right.',
#   'Comment_Author': '@Mr_sha.h',
#   'Comment_Published': '2024-11-15T09:14:36Z'},
#  {'Comment_Id': 'UgwpM5TmkBdlvCDSA914AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'i am waiting',
#   'Comment_Author': '@prasathjmp7565',
#   'Comment_Published': '2024-11-14T13:10:42Z'},
#  {'Comment_Id': 'UgzUSp2r9nqDtJsVaC54AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'hii',
#   'Comment_Author': '@prasathjmp7565',
#   'Comment_Published': '2024-11-14T13:10:27Z'},
#  {'Comment_Id': 'UgymWdi7cW1JpkpvDWJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Pk present',
#   'Comment_Author': '@praveen9467',
#   'Comment_Published': '2024-11-14T11:32:33Z'},
#  {'Comment_Id': 'Ugz_rantJI1MjtRU3F14AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Stay happy and blessed by keeping people happy and alive🖤💯',
#   'Comment_Author': '@christophers2717',
#   'Comment_Published': '2024-11-14T07:48:51Z'},
#  {'Comment_Id': 'Ugw9N9Hq-gpjvTOh9MZ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Anna Bangalore vanga!!!',
#   'Comment_Author': '@rishim7769',
#   'Comment_Published': '2024-11-14T04:26:24Z'},
#  {'Comment_Id': 'UgzGBQlUpM9dgzHLHJx4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=358">5:58</a> This is my personal one. ❤',
#   'Comment_Author': '@manokishore2472',
#   'Comment_Published': '2024-11-13T16:44:12Z'},
#  {'Comment_Id': 'UgzYx5HRrztVkQ6fZEN4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=380">6:20</a>🥺❤\u200d🩹🫂',
#   'Comment_Author': '@_370',
#   'Comment_Published': '2024-11-13T14:39:17Z'},
#  {'Comment_Id': 'UgyBDFL7hIUJ78mTwxh4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Enna bgm nu therincha sollunga pls <a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=501">8:21</a>',
#   'Comment_Author': '@selvarajkrish3409',
#   'Comment_Published': '2024-11-13T10:44:12Z'},
#  {'Comment_Id': 'UgxXxrWoGcoXOx7uUAZ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'அண்ணா❤',
#   'Comment_Author': '@brindafrancis2592',
#   'Comment_Published': '2024-11-13T10:35:37Z'},
#  {'Comment_Id': 'UgwO7FzsdMb2SD62sLB4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Anna Bangalore vaga😭',
#   'Comment_Author': '@Jeeva-m1h',
#   'Comment_Published': '2024-11-13T08:52:21Z'},
#  {'Comment_Id': 'UgxKw6BEUOYkF1nUhFl4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '❤❤',
#   'Comment_Author': '@PeriyannanpillaiRajeethan',
#   'Comment_Published': '2024-11-13T06:13:40Z'},
#  {'Comment_Id': 'UgxTomJPDu3nUVZYilp4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Oruvarai  kavalai maranthu sirika vaipathe miga kafimaiyana kalai 😊😊',
#   'Comment_Author': '@lakshminarayanan1161',
#   'Comment_Published': '2024-11-13T05:30:45Z'},
#  {'Comment_Id': 'UgwHW-bNQcDL_CFsZjJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Ending vera level',
#   'Comment_Author': '@Fathi2211',
#   'Comment_Published': '2024-11-13T04:42:34Z'},
#  {'Comment_Id': 'UgwiYnVvm3ig0mYqUS54AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'அடுத்த விருந்து கும்பகோணம் அருகே  ❤❤❤❤❤',
#   'Comment_Author': '@Sanjai_003',
#   'Comment_Published': '2024-11-13T02:18:00Z'},
#  {'Comment_Id': 'Ugy2AQ56Ysro6gYHxMJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Bro madurai kitaa varathuu😍',
#   'Comment_Author': '@TamilSelvan-g1e',
#   'Comment_Published': '2024-11-12T22:06:03Z'},
#  {'Comment_Id': 'UgzGSbWyqw_9ZJe6hOJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=823">13:43</a> ending😂',
#   'Comment_Author': '@GOL_D_ACE-u2z',
#   'Comment_Published': '2024-11-12T19:21:00Z'},
#  {'Comment_Id': 'UgxG8M1C99kpJE5BtaV4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=765">12:45</a> ❤❤❤😂',
#   'Comment_Author': '@ingaonnuillamamey_7788',
#   'Comment_Published': '2024-11-12T17:39:15Z'},
#  {'Comment_Id': 'UgwD8K8nXcCrPMQcXct4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Siddhu naa 😌❤️✨💎',
#   'Comment_Author': '@selfiaddicts9830',
#   'Comment_Published': '2024-11-12T17:22:41Z'},
#  {'Comment_Id': 'Ugyd8IqT1CqcdFpWKlR4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Please come to Bangalore 🙏🏽🥺',
#   'Comment_Author': '@Manuvlogs2004',
#   'Comment_Published': '2024-11-12T16:39:41Z'},
#  {'Comment_Id': 'UgzJCFVR3EGfo73ZXat4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'அண்ணா எங்கண்ணா சூரிய Bro எந்த வீடியோலமே இல்ல',
#   'Comment_Author': '@nalinofficial_7708',
#   'Comment_Published': '2024-11-12T15:25:09Z'},
#  {'Comment_Id': 'UgzVeXfdOftPN83tQW14AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'அண்ணா இந்த விருந்து பொல் ஒரு விருந்து தமிழ் நாட்டில் ஒரு விருந்து பொட்டால்😊 நல்ல இருக்கும் அண்ணா தானம் செய்ய பெரிய மனசு வேணும் அண்ணா இன்னும் 💯 வயது ஆயிசு வாழ்விங்க அண்ணா வால்த்துக்கல் அண்ணா ❤❤❤🙏🙏🙏🙏🙏🙏🙏🙏',
#   'Comment_Author': '@Jayasurya75thiraviyamJayasurya',
#   'Comment_Published': '2024-11-12T14:13:41Z'},
#  {'Comment_Id': 'UgyEA8bQCPi5KPcFrHF4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=796">13:16</a> hindi camera man ahh vachukaga bro😅',
#   'Comment_Author': '@TMN_GAMER',
#   'Comment_Published': '2024-11-12T11:12:18Z'},
#  {'Comment_Id': 'UgzBou1ydILHmAKxqzV4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Nanum kamatchi Josiyer street than Kmula😂',
#   'Comment_Author': '@shreenidhisundararajan',
#   'Comment_Published': '2024-11-12T10:46:16Z'},
#  {'Comment_Id': 'UgzbHHXm9sX_WCklJLd4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Sri lanka eppa bro',
#   'Comment_Author': '@kapeshan884',
#   'Comment_Published': '2024-11-12T09:46:32Z'},
#  {'Comment_Id': 'UgzRwlpunrGv9cTv4t14AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '❤😂🎉',
#   'Comment_Author': '@SajithaNoofa',
#   'Comment_Published': '2024-11-12T08:42:29Z'},
#  {'Comment_Id': 'Ugx4-EvJujpEY-7PSPh4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '❤️',
#   'Comment_Author': '@CRDURGANANDHINIS',
#   'Comment_Published': '2024-11-12T07:52:33Z'},
#  {'Comment_Id': 'Ugw6YOEKFWNzCGhXJBR4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=705">11:45</a> cherry vlogs 🙌🏻',
#   'Comment_Author': '@dhileep1296',
#   'Comment_Published': '2024-11-12T07:30:05Z'},
#  {'Comment_Id': 'UgzaICj9Iy1kWFWxd-h4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Kodaikanal......',
#   'Comment_Author': '@JancyJohn-o3y',
#   'Comment_Published': '2024-11-12T06:53:52Z'},
#  {'Comment_Id': 'UgxHOTqllcUFqePX5994AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Pondicherry virundhu😢😢😢',
#   'Comment_Author': '@Chemiscal',
#   'Comment_Published': '2024-11-12T06:20:46Z'},
#  {'Comment_Id': 'UgxIrzn_p2pD_2rCKcF4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Advance wishes for 10 million',
#   'Comment_Author': '@sanjaydharani4262',
#   'Comment_Published': '2024-11-12T04:45:11Z'},
#  {'Comment_Id': 'UgynWU87cAn8jlGWLO14AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Anna bg ah kanom.... 😢',
#   'Comment_Author': '@IndhuMathi-db8sr',
#   'Comment_Published': '2024-11-12T04:19:06Z'},
#  {'Comment_Id': 'UgwhvOZvYqBplYMx71x4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Not me crying while having nasi lemak for breakfast!!!😭😭😭😭😭',
#   'Comment_Author': '@linaaruldass6044',
#   'Comment_Published': '2024-11-12T04:04:49Z'},
#  {'Comment_Id': 'UgxUKvxRunnLOUxSPiR4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Vj siddhu Anna .❤️\u200d🩹💎',
#   'Comment_Author': '@ragulramesh3048',
#   'Comment_Published': '2024-11-12T02:33:27Z'},
#  {'Comment_Id': 'UgwdNr9PRK2YvbPdNaB4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Yoov siddhu na amaran padatha Vida athigama ala vaikringa na',
#   'Comment_Author': '@kingstong1148',
#   'Comment_Published': '2024-11-12T01:06:37Z'},
#  {'Comment_Id': 'UgwE7ZQjkm1FpRpnlhJ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'நல்ல இரு போடா ❤❤❤',
#   'Comment_Author': '@SuperSathishbabu',
#   'Comment_Published': '2024-11-11T23:58:03Z'},
#  {'Comment_Id': 'Ugwdsh05WS-Uldrs8oB4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Anna unga big fan tq your team  anna<br>But ungalutai sucess  etha mathi ellarumkku saptu potathutan anna I&#39;m very happy..❤❤',
#   'Comment_Author': '@RS-Creation480',
#   'Comment_Published': '2024-11-11T19:57:04Z'},
#  {'Comment_Id': 'Ugz0Kj3DdbAtsEc-DAB4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Nov summa summa ala vaika koodathy😢😢😢',
#   'Comment_Author': '@rammanju2640',
#   'Comment_Published': '2024-11-11T19:15:08Z'},
#  {'Comment_Id': 'UgxgQtpvEKqXbD4AVpF4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=GWx3nMbWOd8&amp;t=822">13:42</a> 😂😂',
#   'Comment_Author': '@kishores1713',
#   'Comment_Published': '2024-11-11T19:02:37Z'},
#  {'Comment_Id': 'Ugz-fivJ79fvhmljznZ4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '❤',
#   'Comment_Author': '@KisgoeKigroe',
#   'Comment_Published': '2024-11-11T18:52:55Z'},
#  {'Comment_Id': 'Ugxxiju_IBQyWzTzb2F4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Madurai',
#   'Comment_Author': '@SenthilKumar-ku2kn',
#   'Comment_Published': '2024-11-11T18:19:41Z'},
#  {'Comment_Id': 'UgyhRvwz7OnCt0-GEG14AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'அடுத்த விருந்து கும்பகோணம் பன்னுங்க அண்ணா🥳❤😁',
#   'Comment_Author': '@abinaya8664',
#   'Comment_Published': '2024-11-11T17:26:05Z'},
#  {'Comment_Id': 'UgwvI45b5GOSv5VQ6Ax4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '<b>PAARI SAALAN FANS HIT LIKE</b>',
#   'Comment_Author': '@sk549',
#   'Comment_Published': '2024-11-11T17:17:01Z'},
#  {'Comment_Id': 'Ugwui2i2Wmi7IXNSLiB4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'Congratulations for 😊',
#   'Comment_Author': '@BalakrishnaBalakrishna-n1q',
#   'Comment_Published': '2024-11-11T17:11:23Z'},
#  {'Comment_Id': 'Ugwis1jpqkpN_DVfUo94AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': 'idhuku mela ena sidhhu anna venum 😍 😍',
#   'Comment_Author': '@mohanapriya9581',
#   'Comment_Published': '2024-11-11T16:42:07Z'},
#  {'Comment_Id': 'UgzuZPNNUGcfbkqEQmV4AaABAg',
#   'Video_Id': 'GWx3nMbWOd8',
#   'Comment_Text': '🎉😂❤',
#   'Comment_Author': '@PraveenKumar-cd4tr',
#   'Comment_Published': '2024-11-11T15:58:42Z'},
#  {'Comment_Id': 'UgylGLnxQS0cPXeD6Sh4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': '❤❤❤😢',
#   'Comment_Author': '@Brindha-je1wl',
#   'Comment_Published': '2024-11-15T16:20:02Z'},
#  {'Comment_Id': 'Ugz7UvnoGguYfdr7QUt4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': 'Anna Dindigul ku oru thadava vanga anna❤❤❤',
#   'Comment_Author': '@ThalapathyChannel1022',
#   'Comment_Published': '2024-11-15T16:19:10Z'},
#  {'Comment_Id': 'UgxaIy-9LcXlPyqKME54AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': 'நீங்கள் மேலும் மேலும் உயரணும் அண்ணா 🥹♥️💪',
#   'Comment_Author': '@renisharenu9525',
#   'Comment_Published': '2024-11-15T14:11:48Z'},
#  {'Comment_Id': 'Ugxw71SkE0KrbUok-ZJ4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': 'Ye pa aluga vaikiringaaaaaa😢❤',
#   'Comment_Author': '@ammuezhil8902',
#   'Comment_Published': '2024-11-15T13:17:09Z'},
#  {'Comment_Id': 'UgwS3mNkIehqFBNnRb94AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': '4 million vanta ahh Kumbakonam vaanga anna❤️',
#   'Comment_Author': '@JayaSri-w6l',
#   'Comment_Published': '2024-11-15T10:14:04Z'},
#  {'Comment_Id': 'UgwlobCphJYdPBu8Btx4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': '🥺🫀',
#   'Comment_Author': '@VEL_ZXOX',
#   'Comment_Published': '2024-11-15T03:39:42Z'},
#  {'Comment_Id': 'UgwTxxwVvWHodeHOKDd4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': 'Come to Canada as well, anna❤',
#   'Comment_Author': '@nithuahil7798',
#   'Comment_Published': '2024-11-15T03:36:54Z'},
#  {'Comment_Id': 'UgysFHwn9O0Uic3aqCN4AaABAg',
#   'Video_Id': 'lz-SC3NwSGY',
#   'Comment_Text': 'Unamayai na kadavul na vj siddhu vlog',
#   'Comment_Author': '@spnspn3530',
#   'Comment_Published': '2024-11-14T19:42:00Z'},
# ...
#   'Comment_Published': '2024-10-19T08:17:23Z'},
#  {'Comment_Id': 'UgxIJGlGIrva8E7WuvN4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'The OG stress buster',
#   'Comment_Author': '@ARUNNISSAL',
#   'Comment_Published': '2024-10-19T07:12:25Z'},
#  {'Comment_Id': 'Ugwb2mnpmH3BTIIY9554AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=h6hVTkLUCf4&amp;t=94">1:34</a> 😂😂😂',
#   'Comment_Author': '@SaravananPanda',
#   'Comment_Published': '2024-10-19T01:44:29Z'},
#  {'Comment_Id': 'UgxKvzE9Mt5yLY17AFp4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=h6hVTkLUCf4&amp;t=700">11:40</a> that moment of<br>Nee than da driveruu unnaiiya vachu thanda Ootaanuuu.... 😂😂😂❤❤',
#   'Comment_Author': '@ramaswamy2983',
#   'Comment_Published': '2024-10-18T13:24:42Z'},
#  {'Comment_Id': 'UgwdiYPjDrv0_oVWo894AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'படுத்துக்கொண்டு வீடியோ பார்க்கும் நண்பர்கள் சார்பாக வீடியோ வெற்றி பெற வாழ்த்துக்கள்',
#   'Comment_Author': '@deenadiyalan',
#   'Comment_Published': '2024-10-18T10:38:07Z'},
#  {'Comment_Id': 'UgzJgVG0TSKTh4livAh4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=h6hVTkLUCf4&amp;t=702">11:42</a> 😂😂😂😂',
#   'Comment_Author': '@niharasamsul',
#   'Comment_Published': '2024-10-18T09:06:34Z'},
#  {'Comment_Id': 'UgxCRRIIUoBt_QALDKV4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Enjoy ❤❤❤',
#   'Comment_Author': '@arunpandiyan4625',
#   'Comment_Published': '2024-10-18T07:02:11Z'},
#  {'Comment_Id': 'UgzVc4sr4oJ2tPcCSL54AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Satish anne dance vere level😂😂😂',
#   'Comment_Author': '@TirukumaranVijayan',
#   'Comment_Published': '2024-10-18T06:08:03Z'},
#  {'Comment_Id': 'UgweyL6kBJbZCKC7ShN4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Super😂😂😂',
#   'Comment_Author': '@maheshwaranmahes7189',
#   'Comment_Published': '2024-10-18T05:13:04Z'},
#  {'Comment_Id': 'Ugzb87rbWmJ2pnr7Dal4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '😂',
#   'Comment_Author': '@mcz.kannan239',
#   'Comment_Published': '2024-10-18T03:42:46Z'},
#  {'Comment_Id': 'Ugztn2NRfp_z2DqCMMR4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Harshatheyyyyyyyy🤍',
#   'Comment_Author': '@priyadharshini-s3v',
#   'Comment_Published': '2024-10-18T03:19:36Z'},
#  {'Comment_Id': 'UgzH771edjEG4S9sLz94AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '🔥🔥🔥🔥🔥',
#   'Comment_Author': '@praveenyaadu1418',
#   'Comment_Published': '2024-10-18T02:26:06Z'},
#  {'Comment_Id': 'Ugyl8hu8ISs6KKRYN5d4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'besakih temple visit pannunga Anna athu 1000 years mela old temple anna🤘🏻🤙🏻😅 Bali la tha irrukhu',
#   'Comment_Author': '@Mukeshvj-27',
#   'Comment_Published': '2024-10-17T22:09:12Z'},
#  {'Comment_Id': 'UgyOX-lC-WEJSIhjoZx4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Pavum glam sam siddhu bro',
#   'Comment_Author': '@tharchaanchaan9706',
#   'Comment_Published': '2024-10-17T19:16:47Z'},
#  {'Comment_Id': 'UgzF2Ie9weP9YkvA1bV4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'kadavule ajith-uh 🎉',
#   'Comment_Author': '@jeron7258',
#   'Comment_Published': '2024-10-17T17:08:53Z'},
#  {'Comment_Id': 'Ugx5WHBRvIrEriKpdd94AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Ongala paakurpa poramaiya iruku na jolly ahh enjoy pandringa',
#   'Comment_Author': '@LogeshLogesh-u5w',
#   'Comment_Published': '2024-10-17T16:22:16Z'},
#  {'Comment_Id': 'UgwDvPmkAjxlooAn8Y94AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': '🎉🎉🎉🎉❤❤❤❤❤',
#   'Comment_Author': '@PraveenPraveen-gu8gh',
#   'Comment_Published': '2024-10-17T16:20:33Z'},
#  {'Comment_Id': 'UgzW5ZuaVzbrhzy6FGV4AaABAg',
#   'Video_Id': 'h6hVTkLUCf4',
#   'Comment_Text': 'Pahhh Enna oru enjoy🙂',
#   'Comment_Author': '@riyachopra2202',
#   'Comment_Published': '2024-10-17T15:50:13Z'},
#  {'Comment_Id': 'Ugw6iNy0I1lXMJ4P-Hd4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=895">14:55</a> 🤣🔥🔥🔥🔥🔥',
#   'Comment_Author': '@ajaylaxman8526',
#   'Comment_Published': '2024-11-15T15:40:53Z'},
#  {'Comment_Id': 'Ugy4TXXCGqsKWDFl6P94AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'steve the great 90s kids crocodile Man. died due to sting ray barb penetrate in to his body not by bite',
#   'Comment_Author': '@arunasasi5321',
#   'Comment_Published': '2024-11-12T17:50:32Z'},
#  {'Comment_Id': 'UgzGbNesY4njz4CrB-d4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'I got it bro😅',
#   'Comment_Author': '@prabakaran1094',
#   'Comment_Published': '2024-11-12T17:09:02Z'},
#  {'Comment_Id': 'Ugw4Lk8j_doyFZs6IDh4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Crocodile ❎ korkadail✅🤣 <a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=629">10:29</a>',
#   'Comment_Author': '@mediamechine853',
#   'Comment_Published': '2024-11-10T16:06:33Z'},
#  {'Comment_Id': 'UgwACyGGUXtlrPHFPlt4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '😅😅😅😅ftv',
#   'Comment_Author': '@yogeshd8731',
#   'Comment_Published': '2024-11-10T16:00:52Z'},
#  {'Comment_Id': 'Ugxivw3_ypsSMX4LemB4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Vera level 😂😂😂😂🎉🎉🎉🎉🎉',
#   'Comment_Author': '@apachetamizha',
#   'Comment_Published': '2024-11-08T16:55:03Z'},
#  {'Comment_Id': 'UgyDxUk8XlDuCp2ZTH54AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=603">10:03</a> Annaiku inaikku ore sattaya annae',
#   'Comment_Author': '@deepan5946',
#   'Comment_Published': '2024-11-05T15:30:00Z'},
#  {'Comment_Id': 'UgxQR9STWLyKr2gVcbh4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F TV ❤❤❤❤❤😂😂😂😂😂😂 da midnight hot show fans anybody',
#   'Comment_Author': '@Vijaymsd2495',
#   'Comment_Published': '2024-11-05T07:34:25Z'},
#  {'Comment_Id': 'Ugzlg9J2xysOISPyWih4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Bro bearku beernutu edit panirukinga',
#   'Comment_Author': '@Digitalvibe_1',
#   'Comment_Published': '2024-11-04T19:28:15Z'},
#  {'Comment_Id': 'Ugz1Bibx4uQkP7i01Px4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '😂😂....',
#   'Comment_Author': '@jeevajeeva8012',
#   'Comment_Published': '2024-11-03T09:50:54Z'},
#  {'Comment_Id': 'UgxPpzc5DO6XcfYTt3F4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '90s mattum sollathinga bro, <br>2004 kid naane pathuruken fashion tv',
#   'Comment_Author': '@karuppaiyavengadesan4802',
#   'Comment_Published': '2024-11-01T05:42:05Z'},
#  {'Comment_Id': 'Ugw5E3QW8MZS8_tb9Ht4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F tv 😂😂',
#   'Comment_Author': '@SADKARL19',
#   'Comment_Published': '2024-10-31T13:46:52Z'},
#  {'Comment_Id': 'UgyPUTm-ySJ9hUBLCmd4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Sidhu anna wakkali nu sonnaru ketucha😂?',
#   'Comment_Author': '@fun_station_vlogs',
#   'Comment_Published': '2024-10-31T12:00:40Z'},
#  {'Comment_Id': 'UgyddgGX6TL46SsJWNx4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Adhu stingray tail adichu sethutaru. Kadichu sethutan soningalae hahaha',
#   'Comment_Author': '@afzalahamed9464',
#   'Comment_Published': '2024-10-30T08:46:26Z'},
#  {'Comment_Id': 'UgwPJbpsNEGJFol-mRF4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'FTV aruma ennaku theriyum 😂😂😂😂😂',
#   'Comment_Author': '@b47-aakashwar41',
#   'Comment_Published': '2024-10-30T05:14:41Z'},
#  {'Comment_Id': 'Ugxfx7D962Axfvq_FKd4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Zmg na enna bro',
#   'Comment_Author': '@irfansaabith',
#   'Comment_Published': '2024-10-29T18:13:58Z'},
#  {'Comment_Id': 'UgyclZftcVkZlx-3Iht4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F tv fanz like podunga❤',
#   'Comment_Author': '@benojilluj7392',
#   'Comment_Published': '2024-10-29T14:15:20Z'},
#  {'Comment_Id': 'UgxCgUniT1Xq_XDzW8t4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=879">14:39</a> 😂👌',
#   'Comment_Author': '@divi_nishann',
#   'Comment_Published': '2024-10-28T15:48:57Z'},
#  {'Comment_Id': 'UgwdSfNAL6Q4exXHlPp4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F tv siddhuna naa pathuruka nalla irukum 6 pm ku apram',
#   'Comment_Author': '@Mohamedusain2357',
#   'Comment_Published': '2024-10-27T17:37:23Z'},
#  {'Comment_Id': 'UgyPeTYLlbQB_9_-T3l4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F tv fans asamble 😎',
#   'Comment_Author': '@MrAandan',
#   'Comment_Published': '2024-10-26T13:18:12Z'},
#  {'Comment_Id': 'UgxCmOQKYoVGFI6Qoml4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '7tunes moon tv 😶',
#   'Comment_Author': '@jawaharshankaranarayanan4946',
#   'Comment_Published': '2024-10-25T18:19:17Z'},
#  {'Comment_Id': 'UgxgEV2fBuXvISTfK3Z4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Ye anna soory annna varumboth konduva anna . Nte malayalam so bad. Soory anna my favorites and my hee vj sidhu anna',
#   'Comment_Author': '@vishnuvishnuvishnu298',
#   'Comment_Published': '2024-10-24T18:18:12Z'},
#  {'Comment_Id': 'Ugy8ri6zRb9l_QGNMhJ4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Annna love from Kerala',
#   'Comment_Author': '@vishnuvishnuvishnu298',
#   'Comment_Published': '2024-10-24T18:14:06Z'},
#  {'Comment_Id': 'UgzXtTK5WRjcem2Dp6l4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F tv was personal 😂',
#   'Comment_Author': '@vishwavijay1546',
#   'Comment_Published': '2024-10-24T18:03:26Z'},
#  {'Comment_Id': 'UgzCgG3IdH_CfbPA_m94AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Ftv fans assemble .. 😂...  Nyt 10.30 ku... 😊',
#   'Comment_Author': '@magesh-xr3yu',
#   'Comment_Published': '2024-10-24T17:35:08Z'},
#  {'Comment_Id': 'UgydH-MhnCfnGnD3SUN4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Bro F tv😂😂😂😂😂',
#   'Comment_Author': '@gowtham9609',
#   'Comment_Published': '2024-10-24T16:28:42Z'},
#  {'Comment_Id': 'Ugwoua-VM6mfiV4FvZx4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=1065">17:45</a> wwe memories❤\u200d🔥❤\u200d🔥 Rey Mysterio oru match ku aprm face reveal panirupaaru siddhu na❤❤',
#   'Comment_Author': '@mohammedaabeeths2066',
#   'Comment_Published': '2024-10-24T09:05:43Z'},
#  {'Comment_Id': 'UgyVYIZLw7vwT1NXvyJ4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Fashion Tv Fans😅😅😅',
#   'Comment_Author': '@__-oz8yk',
#   'Comment_Published': '2024-10-24T04:40:20Z'},
#  {'Comment_Id': 'UgxSA2mcCxkIFl-ppkd4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '😂',
#   'Comment_Author': '@den_wonder_kid',
#   'Comment_Published': '2024-10-23T16:00:19Z'},
#  {'Comment_Id': 'UgyzWUwDTpB8NCpiqdN4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'I m also Steve fan anna🤙',
#   'Comment_Author': '@sumandon8533',
#   'Comment_Published': '2024-10-23T15:35:32Z'},
#  {'Comment_Id': 'UgxeYew2n9ekO5Spdz14AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'I&#39;m a fan of Steve Irwin also..❤☺️',
#   'Comment_Author': '@KalaiVani-Vra',
#   'Comment_Published': '2024-10-23T12:48:05Z'},
#  {'Comment_Id': 'UgycsW6rEqP8rNGr9z14AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=305">5:05</a>😂😂',
#   'Comment_Author': '@AshokAshok-ql9pt',
#   'Comment_Published': '2024-10-23T11:26:43Z'},
#  {'Comment_Id': 'UgxGPhjyWqko0aHa59B4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Steew',
#   'Comment_Author': '@kumaranrock1912',
#   'Comment_Published': '2024-10-23T09:30:44Z'},
#  {'Comment_Id': 'Ugxr2XA4LuomRiQPoz94AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '90&#39;s 😅😂❤',
#   'Comment_Author': '@prakashvjpprakash1133',
#   'Comment_Published': '2024-10-22T17:32:59Z'},
#  {'Comment_Id': 'UgzTpAPHFiRVgNopF1J4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Fashion Tv Rasigargal na nangal😂',
#   'Comment_Author': '@rjsharaneditz9162',
#   'Comment_Published': '2024-10-22T10:29:32Z'},
#  {'Comment_Id': 'Ugx_h07DlxbHY3Wa9uN4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'F Tv fans😂',
#   'Comment_Author': '@rgisamvlogs',
#   'Comment_Published': '2024-10-22T07:32:28Z'},
#  {'Comment_Id': 'Ugwy_DAJXhIKfHHyf2p4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=606">10:06</a> Same shirt as Dubai and now ,, Siddu anna',
#   'Comment_Author': '@DoorStep_SalesMan',
#   'Comment_Published': '2024-10-22T04:43:12Z'},
#  {'Comment_Id': 'UgzKnz19QW_HAhc7ch94AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Bro, Stingray is really dangerous one and Steve got sting in his heart....',
#   'Comment_Author': '@vigneshwarankabilan1686',
#   'Comment_Published': '2024-10-21T23:03:03Z'},
#  {'Comment_Id': 'UgwgfZpFUDUq_KjMZ114AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=307">5:07</a> 🤣🤣🤣',
#   'Comment_Author': '@VICKY-fi7ct',
#   'Comment_Published': '2024-10-21T18:05:58Z'},
#  {'Comment_Id': 'UgzYcLBve8ZLeA7BLhZ4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Apa Undertaker uhm Kane uhm Annan thambi illayaa🙄',
#   'Comment_Author': '@dhinakaran8348',
#   'Comment_Published': '2024-10-21T15:27:08Z'},
#  {'Comment_Id': 'UgxGwP6hIZIyd2xDA_B4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=955">15:55</a>',
#   'Comment_Author': '@Ramkumar-xg4uj',
#   'Comment_Published': '2024-10-21T14:48:17Z'},
#  {'Comment_Id': 'UgyUKoUyUP3DFj2o2_R4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Man vs wild ---&gt;',
#   'Comment_Author': '@manikumar66666',
#   'Comment_Published': '2024-10-21T10:19:53Z'},
#  {'Comment_Id': 'UgyO1hwDqG1FcRbSjt14AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Adengapppaaa inthe kane munjile acid adiche kathaiye ulagam fullaaq yemaathirukaanunqalaa😮',
#   'Comment_Author': '@arjunbai7925',
#   'Comment_Published': '2024-10-21T09:47:46Z'},
#  {'Comment_Id': 'UgxKxPH_Jk77sBlMR5l4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=1272">21:12</a> z engine ??????',
#   'Comment_Author': '@ideaenlightened1516',
#   'Comment_Published': '2024-10-21T09:37:39Z'},
#  {'Comment_Id': 'Ugw6qisf-7TMQ_aMRZV4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="http://www.youtube.com/results?search_query=%23steve">#steve</a> Irvin fan',
#   'Comment_Author': '@BCH_PraveenKumarD',
#   'Comment_Published': '2024-10-21T08:09:29Z'},
#  {'Comment_Id': 'UgykZkC3veb6jJSH5254AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=597">9:57</a> Same dress siddhu anna',
#   'Comment_Author': '@boomikas6422',
#   'Comment_Published': '2024-10-21T06:28:52Z'},
#  {'Comment_Id': 'UgzWEBBoreUqEYA3B2p4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'I grew up watching Steve Irwin too. He is such a brave person. He died because of the stingray&#39;s barb. The barb is placed near its tail. The barb contains venom. The barb was stung near his chest, which made him collapse.',
#   'Comment_Author': '@saigeerthanjaly8041',
#   'Comment_Published': '2024-10-21T05:10:36Z'},
#  {'Comment_Id': 'Ugxgq969VKhIaW6grtd4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=1069">17:49</a> bear grylls fan umm irkom. 😊',
#   'Comment_Author': '@Vicky-fl7et',
#   'Comment_Published': '2024-10-20T19:49:52Z'},
#  {'Comment_Id': 'UgxhIZms79aj24eCnZN4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': 'Fashion TV midnight divas ❤ 11 pm to 01 am 😊<br>Also ss music midnight masala ❤',
#   'Comment_Author': '@IndrajithMaverick',
#   'Comment_Published': '2024-10-20T19:38:46Z'},
#  {'Comment_Id': 'Ugz5wwLKxrsJkyXiqBZ4AaABAg',
#   'Video_Id': 'z9rbAGIMXB4',
#   'Comment_Text': '<a href="https://www.youtube.com/watch?v=z9rbAGIMXB4&amp;t=694">11:34</a> sheriff bro taking veeramani voice 🤣.. deii P**ta porikki 😂',
#   'Comment_Author': '@vivekbaskar6899',
#   'Comment_Published': '2024-10-20T18:56:11Z'},
#  ...]

# %% [markdown]
# ##### PLAYLIST INFORMATION

# %%
#get_playlist_details

def get_playlist_details(channel_id):
        next_page_token=None
        All_data=[]
        while True:
                request=youtube.playlists().list(
                        part='snippet,contentDetails',
                        channelId=channel_id,
                        maxResults=50,
                        pageToken=next_page_token
                )
                response=request.execute()

                for item in response['items']:
                        data=dict(Playlist_Id=item['id'],
                                Title=item['snippet']['title'],
                                Channel_Id=item['snippet']['channelId'],
                                Channel_Name=item['snippet']['channelTitle'],
                                PublishedAt=item['snippet']['publishedAt'],
                                Video_Count=item['contentDetails']['itemCount'])
                        All_data.append(data)

                next_page_token=response.get('nextPageToken')
                if next_page_token is None:
                        break
        return All_data

# %%
playlist_information = get_playlist_details("UCJcCB-QYPIBcbKcBQOTwhiA")

# %%
playlist_information
# Out:
# [{'Playlist_Id': 'PLjnNpn3gLsF-b8sJ0I_niPj3bZcwaQZ65',
#   'Title': 'Malaysia Series 💥🥳 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-11-03T04:16:54Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLjnNpn3gLsF_9rupoXwEQtJQePzNZn4H9',
#   'Title': 'Bali Series | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-10-05T15:47:42Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLjnNpn3gLsF-k_2dai2dlpdW6vAHVuHoM',
#   'Title': 'Office Samayal🥳 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-10-03T11:21:02Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLjnNpn3gLsF82xQ9AiV6RLbcAulOWLxjf',
#   'Title': 'Japan Series✨🥳 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-09-04T09:17:13Z',
#   'Video_Count': 15},
#  {'Playlist_Id': 'PLjnNpn3gLsF_VuXLz4OAlrUM557qyl4D7',
#   'Title': '3 Million Celebration  Kovai Virundhu 🥳🔥| Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-08-23T09:25:05Z',
#   'Video_Count': 7},
#  {'Playlist_Id': 'PLjnNpn3gLsF9ccYQ-_sp4WETqlFhrob2K',
#   'Title': 'Arupadai Trip😍🥳| Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-08-08T13:02:22Z',
#   'Video_Count': 9},
#  {'Playlist_Id': 'PLjnNpn3gLsF_MP95A2jBtGvy0qLRS6Or1',
#   'Title': 'Hyderabad series | VJ Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-07-17T08:06:08Z',
#   'Video_Count': 8},
#  {'Playlist_Id': 'PLjnNpn3gLsF9P28ayyfxnrOSeCTohE9wy',
#   'Title': 'Bike Trip Series 🏍 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-06-26T09:10:20Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLjnNpn3gLsF9GEyykK1cDplKCAFIs9e_d',
#   'Title': 'Movie - Re-release Promos',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-06-17T10:41:01Z',
#   'Video_Count': 2},
#  {'Playlist_Id': 'PLjnNpn3gLsF8jEMdug9XumEBSpFljCQoo',
#   'Title': '1 Year Celebration💥🥳 | Sports Day',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-06-17T09:06:28Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLjnNpn3gLsF8R5zPI8kG7_-N56cRndJqv',
#   'Title': 'South Korea Series💜 | | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-05-06T09:13:53Z',
#   'Video_Count': 14},
#  {'Playlist_Id': 'PLjnNpn3gLsF8y6CegqrMc3C7ThEoN01ak',
#   'Title': 'Vj Siddhu Chennai Virundhu 🎉 🍽️ | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-04-21T03:54:00Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLjnNpn3gLsF_FlphknzMM-ltOTvZUukzv',
#   'Title': 'Dubai Series 🌴🌎 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-03-30T23:35:57Z',
#   'Video_Count': 13},
#  {'Playlist_Id': 'PLjnNpn3gLsF9yUBhHcgQxBLg9iTt2qJo7',
#   'Title': 'Salem Vlog 😍 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-03-14T09:25:33Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLjnNpn3gLsF9AFGyw6oXvFmFlLapSP_vX',
#   'Title': 'Sri Lanka Series 🤩 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-02-09T09:13:44Z',
#   'Video_Count': 12},
#  {'Playlist_Id': 'PLjnNpn3gLsF-uH5uKfoYPSA82BQK_sFeF',
#   'Title': 'மொட்டமாடி Party 🤙🏻| Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-02-07T11:52:41Z',
#   'Video_Count': 11},
#  {'Playlist_Id': 'PLjnNpn3gLsF8k9kwp2YPHxS1T8KroX_tI',
#   'Title': 'Vaanga படம் பாப்போம்🔥🎥 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-02-03T18:30:53Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLjnNpn3gLsF-4Rv28G2fRVj8j836aWJZ8',
#   'Title': 'Instagram Series😂 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-01-26T08:33:27Z',
#   'Video_Count': 6},
#  {'Playlist_Id': 'PLjnNpn3gLsF9LK_bejGuygB7Avu1MNz3x',
#   'Title': 'Home Tour - Full Movie',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2024-01-21T04:14:01Z',
#   'Video_Count': 1},
#  {'Playlist_Id': 'PLjnNpn3gLsF_5vKvXLjtO03mi8uuOsTCq',
#   'Title': 'Kolkata Series🌉 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-12-15T11:35:49Z',
#   'Video_Count': 13},
#  {'Playlist_Id': 'PLjnNpn3gLsF-NGdVcqVYT06MQ-1ukqRLg',
#   'Title': 'Kodaikanal Series🌳 | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-11-15T12:35:36Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLjnNpn3gLsF9D8VG6t0glsRBxVZwLeDSB',
#   'Title': 'Thailand Series | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-09-27T10:08:59Z',
#   'Video_Count': 16},
#  {'Playlist_Id': 'PLjnNpn3gLsF8OUCxfR83U2pDjzlLTKwsy',
#   'Title': 'Home Tour | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-09-26T16:38:01Z',
#   'Video_Count': 5},
#  {'Playlist_Id': 'PLjnNpn3gLsF-1_D7NJ_OUZCkZriZUZ176',
#   'Title': 'Goa | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-09-14T06:57:29Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLjnNpn3gLsF_VHvqxyuStH1-NYbxq-ZVf',
#   'Title': 'TASMAC Sidedish Review | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-07-24T11:11:40Z',
#   'Video_Count': 4},
#  {'Playlist_Id': 'PLjnNpn3gLsF-oTmQ9yqKnd1XdTGa7KV7O',
#   'Title': 'Food Review | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-07-24T11:10:36Z',
#   'Video_Count': 10},
#  {'Playlist_Id': 'PLjnNpn3gLsF8ndQg_j-vnKlUeQU1LYX7L',
#   'Title': 'Shorts | VJ Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-06-29T07:10:36Z',
#   'Video_Count': 0},
#  {'Playlist_Id': 'PLjnNpn3gLsF8v7EdZFvgEq2fAuHdByeEH',
#   'Title': 'Vlogs | Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Channel_Name': 'Vj Siddhu Vlogs',
#   'PublishedAt': '2023-06-20T10:24:15Z',
#   'Video_Count': 69}]

# %% [markdown]
# ### MONGODB PART

# %%
#upload to mongoDB

client=pymongo.MongoClient("mongodb+srv://ArunAK:ARUNAKDS@cluster0.bpcx6.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0")

db=client["AK_data"]

# %%
def Akch_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_videos_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)

    coll1=db["Akch_details"]
    coll1.insert_one({"channel_information":ch_details,"playlist_information":pl_details,
                      "video_information":vi_details,"comment_information":com_details})
    
    return "upload completed successfully"

# %%
insert = Akch_details("UCk8CTmd4H4S1m71DBbrUa2A")

# %%
insert
# Out:
# 'upload completed successfully'

# %% [markdown]
# ### TABLE CREATION

# %% [markdown]
# ##### CHANNELS TABLE

# %%
def channels_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="222005",
                        database="AK_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query = '''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()

    try:
        create_query='''create table if not exists channels(Channel_Name varchar(100),
                                                            Channel_Id varchar(80) primary key,
                                                            Subscribers bigint,
                                                            Views bigint,
                                                            Total_Videos int,
                                                            Channel_Description text,
                                                            Playlist_Id varchar(80))'''
        cursor.execute(create_query)
        mydb.commit()
    except:
        
        print("Channels table already created")
        
    ch_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
        
    df = pd.DataFrame(ch_list)

    for index,row in df.iterrows():
        insert_query='''insert into channels(Channel_Name,
                                            Channel_Id,
                                            Subscribers,
                                            Views,
                                            Total_Videos,
                                            Channel_Description,
                                            Playlist_Id)
                            
                                            values(%s,%s,%s,%s,%s,%s,%s)'''
        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Subscribers'],
                row['Views'],
                row['Total_Videos'],
                row['Channel_Description'],
                row['Playlist_Id'])

        try:
            cursor.execute(insert_query,values)
            mydb.commit()

        except:
            print("Channel values are already inserted")

# %%
ch_list = []
db = client["AK_data"]
coll1 = db["Akch_details"]

for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
    ch_list.append(ch_data["channel_information"])
    
df = pd.DataFrame(ch_list)

# %%
df
# Out:
#               Channel_Name                Channel_Id Subscribers      Views  \
# 0          Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA     3600000  743017547
# 1  Sadhana Movies Reaction  UCasqy7KT_3omXlWynKCEMZw       21700    5218213
# 2               GOSU Vlogs  UCpIyxQjHtn4Ddiyv1yBfbQw      351000   26395258
# 3         Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A        1070      29314
#
#   Total_Videos                                Channel_Description  \
# 0          277  Hello guys! Welcome to my channel! !\n\nMy cha...
# 1          575
# 2          112  Hey there! Welcome to GOSU Vlogs!\n\nDive into...
# 3          167                   this is only educational purpose
#
#                 Playlist_Id
# 0  UUJcCB-QYPIBcbKcBQOTwhiA
# 1  UUasqy7KT_3omXlWynKCEMZw
# 2  UUpIyxQjHtn4Ddiyv1yBfbQw
# 3  UUk8CTmd4H4S1m71DBbrUa2A

# %%
ch_list
# Out:
# [{'Channel_Name': 'Vj Siddhu Vlogs',
#   'Channel_Id': 'UCJcCB-QYPIBcbKcBQOTwhiA',
#   'Subscribers': '3600000',
#   'Views': '743017547',
#   'Total_Videos': '277',
#   'Channel_Description': 'Hello guys! Welcome to my channel! !\n\nMy channel will take you into the details of my life and give a glimpse of what inspires me to do what I do. \n\nGet ready to watch my latest vlogs depicting life in detail that will make you slow down and enjoy life a little better. Subscribe to my channel and stay connected!  \n\nFor Business inquiries please contact us :7200571056\nGmail : vjsidduvlogsadv@gmail.com \n______________________________\n\nDigital Partner - Divo\nDivo is one of the leading digital media companies in South India working with brands and content creators across genres.\n',
#   'Playlist_Id': 'UUJcCB-QYPIBcbKcBQOTwhiA'},
#  {'Channel_Name': 'Sadhana Movies Reaction',
#   'Channel_Id': 'UCasqy7KT_3omXlWynKCEMZw',
#   'Subscribers': '21700',
#   'Views': '5218213',
#   'Total_Videos': '575',
#   'Channel_Description': '',
#   'Playlist_Id': 'UUasqy7KT_3omXlWynKCEMZw'}]

# %% [markdown]
# ##### PLAYLISTS TABLE

# %%
def playlist_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="222005",
                        database="AK_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query = '''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists playlists(Playlist_Id varchar(100) primary key,
                                                        Title varchar(100),
                                                        Channel_Id varchar(100),
                                                        Channel_Name varchar(100),
                                                        PublishedAt timestamp,
                                                        Video_Count int
                                                        )'''

    cursor.execute(create_query)
    mydb.commit()

    pl_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
            
    df1 = pd.DataFrame(pl_list) 

    for index,row in df1.iterrows():
        insert_query='''insert into playlists(Playlist_Id,
                                            Title,
                                            Channel_Id,
                                            Channel_Name,
                                            PublishedAt,
                                            Video_Count
                                            )
                                            
                                            values(%s,%s,%s,%s,%s,%s)'''
        
        values=(row['Playlist_Id'],
                row['Title'],
                row['Channel_Id'],
                row['Channel_Name'],
                row['PublishedAt'],
                row['Video_Count']
                )

        
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
pl_list = []
db = client["AK_data"]
coll1 = db["Akch_details"]

for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
    for i in range(len(pl_data["playlist_information"])):
        pl_list.append(pl_data["playlist_information"][i])
        
df1 = pd.DataFrame(pl_list)

# %%
df1
# Out:
#                            Playlist_Id  \
# 0   PLjnNpn3gLsF-b8sJ0I_niPj3bZcwaQZ65
# 1   PLjnNpn3gLsF_9rupoXwEQtJQePzNZn4H9
# 2   PLjnNpn3gLsF-k_2dai2dlpdW6vAHVuHoM
# 3   PLjnNpn3gLsF82xQ9AiV6RLbcAulOWLxjf
# 4   PLjnNpn3gLsF_VuXLz4OAlrUM557qyl4D7
# 5   PLjnNpn3gLsF9ccYQ-_sp4WETqlFhrob2K
# 6   PLjnNpn3gLsF_MP95A2jBtGvy0qLRS6Or1
# 7   PLjnNpn3gLsF9P28ayyfxnrOSeCTohE9wy
# 8   PLjnNpn3gLsF9GEyykK1cDplKCAFIs9e_d
# 9   PLjnNpn3gLsF8jEMdug9XumEBSpFljCQoo
# 10  PLjnNpn3gLsF8R5zPI8kG7_-N56cRndJqv
# 11  PLjnNpn3gLsF8y6CegqrMc3C7ThEoN01ak
# 12  PLjnNpn3gLsF_FlphknzMM-ltOTvZUukzv
# 13  PLjnNpn3gLsF9yUBhHcgQxBLg9iTt2qJo7
# 14  PLjnNpn3gLsF9AFGyw6oXvFmFlLapSP_vX
# 15  PLjnNpn3gLsF-uH5uKfoYPSA82BQK_sFeF
# 16  PLjnNpn3gLsF8k9kwp2YPHxS1T8KroX_tI
# 17  PLjnNpn3gLsF-4Rv28G2fRVj8j836aWJZ8
# 18  PLjnNpn3gLsF9LK_bejGuygB7Avu1MNz3x
# 19  PLjnNpn3gLsF_5vKvXLjtO03mi8uuOsTCq
# 20  PLjnNpn3gLsF-NGdVcqVYT06MQ-1ukqRLg
# 21  PLjnNpn3gLsF9D8VG6t0glsRBxVZwLeDSB
# 22  PLjnNpn3gLsF8OUCxfR83U2pDjzlLTKwsy
# 23  PLjnNpn3gLsF-1_D7NJ_OUZCkZriZUZ176
# 24  PLjnNpn3gLsF_VHvqxyuStH1-NYbxq-ZVf
# 25  PLjnNpn3gLsF-oTmQ9yqKnd1XdTGa7KV7O
# 26  PLjnNpn3gLsF8ndQg_j-vnKlUeQU1LYX7L
# 27  PLjnNpn3gLsF8v7EdZFvgEq2fAuHdByeEH
# 28  PLeo9oCdAaMy4j7EgYpIHbijXYjMs4aIK5
# 29  PLeo9oCdAaMy4pdh3O_EyVL8qkF4ILNnBI
# 30  PLeo9oCdAaMy6wQWNdEfUQwhc1aAsHnm5I
# 31  PLeo9oCdAaMy6a3-8Vem1cxXzw0NhmmZVJ
# 32  PLyV8957QEMsyQk5ar9ByUSM6iYzTXZhOO
# 33  PLyV8957QEMswy1Ivm3N5OmiEhcvHY-Tz3
# 34  PLyV8957QEMsyISp4VZrK-HhENOy-Ziu3c
# 35  PLyV8957QEMswlql3fic14XUzIAPiVQOqH
# 36  PLyV8957QEMswMxSs_uDYGutZlOzaGbf3C
# 37  PLyV8957QEMswelZfnh0lSnwVBBOHes_5c
# 38  PLk251usQgaVe2KHxIVtqazyEheRpE_XE_
#
#                                                 Title  \
# 0                Malaysia Series 💥🥳 | Vj Siddhu Vlogs
# 1                       Bali Series | Vj Siddhu Vlogs
# 2                   Office Samayal🥳 | Vj Siddhu Vlogs
# 3                    Japan Series✨🥳 | Vj Siddhu Vlogs
# 4   3 Million Celebration  Kovai Virundhu 🥳🔥| Vj S...
# 5                    Arupadai Trip😍🥳| Vj Siddhu Vlogs
# 6                  Hyderabad series | VJ Siddhu Vlogs
# 7                Bike Trip Series 🏍 | Vj Siddhu Vlogs
# 8                           Movie - Re-release Promos
# 9                   1 Year Celebration💥🥳 | Sports Day
# 10            South Korea Series💜 | | Vj Siddhu Vlogs
# 11  Vj Siddhu Chennai Virundhu 🎉 🍽️ | Vj Siddhu Vlogs
# 12                  Dubai Series 🌴🌎 | Vj Siddhu Vlogs
# 13                     Salem Vlog 😍 | Vj Siddhu Vlogs
# 14               Sri Lanka Series 🤩 | Vj Siddhu Vlogs
# 15                மொட்டமாடி Party 🤙🏻| Vj Siddhu Vlogs
# 16           Vaanga படம் பாப்போம்🔥🎥 | Vj Siddhu Vlogs
# 17                Instagram Series😂 | Vj Siddhu Vlogs
# 18                             Home Tour - Full Movie
# 19                  Kolkata Series🌉 | Vj Siddhu Vlogs
# 20               Kodaikanal Series🌳 | Vj Siddhu Vlogs
# 21                  Thailand Series | Vj Siddhu Vlogs
# 22                        Home Tour | Vj Siddhu Vlogs
# 23                              Goa | Vj Siddhu Vlogs
# 24           TASMAC Sidedish Review | Vj Siddhu Vlogs
# 25                      Food Review | Vj Siddhu Vlogs
# 26                           Shorts | VJ Siddhu Vlogs
# 27                            Vlogs | Vj Siddhu Vlogs
# 28                                            Kannada
# 29                                              tamil
# 30                                             Telugu
# 31                                          Malayalam
# 32                        Cooking Vlog 🔥👌| GOSU Vlogs
# 33                           VGP Vlogs🤩😍 | GOSU Vlogs
# 34                        Munnar Trip 🤩🥳 | GOSU Vlogs
# 35                                Vlogs🤩🥳| GOSU Vlogs
# 36                                             Shorts
# 37                           BTS Vlogs 😂🥳| GOSU Vlogs
# 38                          evevryday market analysis
#
#                   Channel_Id             Channel_Name           PublishedAt  \
# 0   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-11-03T04:16:54Z
# 1   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-10-05T15:47:42Z
# 2   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-10-03T11:21:02Z
# 3   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-09-04T09:17:13Z
# 4   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-08-23T09:25:05Z
# 5   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-08-08T13:02:22Z
# 6   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-07-17T08:06:08Z
# 7   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-06-26T09:10:20Z
# 8   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-06-17T10:41:01Z
# 9   UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-06-17T09:06:28Z
# 10  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-05-06T09:13:53Z
# 11  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-04-21T03:54:00Z
# 12  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-03-30T23:35:57Z
# 13  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-03-14T09:25:33Z
# 14  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-02-09T09:13:44Z
# 15  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-02-07T11:52:41Z
# 16  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-02-03T18:30:53Z
# 17  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-01-26T08:33:27Z
# 18  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2024-01-21T04:14:01Z
# 19  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-12-15T11:35:49Z
# 20  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-11-15T12:35:36Z
# 21  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-09-27T10:08:59Z
# 22  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-09-26T16:38:01Z
# 23  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-09-14T06:57:29Z
# 24  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-07-24T11:11:40Z
# 25  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-07-24T11:10:36Z
# 26  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-06-29T07:10:36Z
# 27  UCJcCB-QYPIBcbKcBQOTwhiA          Vj Siddhu Vlogs  2023-06-20T10:24:15Z
# 28  UCasqy7KT_3omXlWynKCEMZw  Sadhana Movies Reaction  2022-10-19T04:19:40Z
# 29  UCasqy7KT_3omXlWynKCEMZw  Sadhana Movies Reaction  2022-09-29T05:30:14Z
# 30  UCasqy7KT_3omXlWynKCEMZw  Sadhana Movies Reaction  2022-09-18T17:02:06Z
# 31  UCasqy7KT_3omXlWynKCEMZw  Sadhana Movies Reaction  2022-09-18T16:57:25Z
# 32  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-11-11T06:14:02Z
# 33  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-07-25T06:25:52Z
# 34  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-07-11T09:20:38Z
# 35  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-06-26T10:31:14Z
# 36  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-06-24T13:48:32Z
# 37  UCpIyxQjHtn4Ddiyv1yBfbQw               GOSU Vlogs  2024-06-20T11:05:58Z
# 38  UCk8CTmd4H4S1m71DBbrUa2A         Trade with prabu  2023-06-08T14:58:15Z
#
#     Video_Count
# 0             8
# 1            12
# 2             4
# 3            15
# 4             7
# 5             9
# 6             8
# 7            11
# 8             2
# 9             5
# 10           14
# 11            6
# 12           13
# 13            4
# 14           12
# 15           11
# 16            5
# 17            6
# 18            1
# 19           13
# 20           10
# 21           16
# 22            5
# 23            4
# 24            4
# 25           10
# 26            0
# 27           69
# 28           24
# 29          117
# 30          335
# 31           47
# 32            3
# 33            3
# 34            5
# 35           20
# 36           75
# 37            3
# 38            3

# %% [markdown]
# ##### VIDEO TABLE

# %%
def videos_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="222005",
                        database="AK_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query = '''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists videos(Channel_Name varchar(100),
                                                    Channel_Id varchar(100),
                                                    Video_Id varchar(30) primary key,
                                                    Title varchar(150),
                                                    Tags text,
                                                    Thumbnail varchar(200),
                                                    Description text,
                                                    Published_Date timestamp,
                                                    Duration interval,
                                                    Views bigint,
                                                    Likes bigint,
                                                    Comments int,
                                                    Favorite_Count int,
                                                    Definition varchar(10),
                                                    Caption_Status varchar(50)
                                                        )'''

    cursor.execute(create_query)
    mydb.commit()

    vi_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
            
    df2 = pd.DataFrame(vi_list)

    for index,row in df2.iterrows():
        insert_query='''insert into videos(Channel_Name,
                                                Channel_Id,
                                                Video_Id,
                                                Title,
                                                Tags,
                                                Thumbnail,
                                                Description,
                                                Published_Date,
                                                Duration,
                                                Views,
                                                Likes,
                                                Comments,
                                                Favorite_Count,
                                                Definition,
                                                Caption_Status
                                            )
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''


        values=(row['Channel_Name'],
                row['Channel_Id'],
                row['Video_Id'],
                row['Title'],
                row['Tags'],
                row['Thumbnail'],
                row['Description'],
                row['Published_Date'],
                row['Duration'],
                row['Views'],
                row['Likes'],
                row['Comments'],
                row['Favorite_Count'],
                row['Definition'],
                row['Caption_Status']
                )

        
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
vi_list = []
db = client["AK_data"]
coll1 = db["Akch_details"]

for vi_data in coll1.find({},{"_id":0,"video_information":1}):
    for i in range(len(vi_data["video_information"])):
        vi_list.append(vi_data["video_information"][i])
        
df2 = pd.DataFrame(vi_list)

# %%
df2
# Out:
#           Channel_Name                Channel_Id     Video_Id  \
# 0      Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA  dEyhsXExCQ4
# 1      Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA  AnZJvhR-TG0
# 2      Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA  U6Vzawt5pd8
# 3      Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA  GWx3nMbWOd8
# 4      Vj Siddhu Vlogs  UCJcCB-QYPIBcbKcBQOTwhiA  lz-SC3NwSGY
# ...                ...                       ...          ...
# 1124  Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A  A3qgW-Topgw
# 1125  Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A  CgkwyU5RZDg
# 1126  Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A  spT2RrBgGS8
# 1127  Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A  a-liBIa2OM0
# 1128  Trade with prabu  UCk8CTmd4H4S1m71DBbrUa2A  EmXhekpwXg4
#
#                                                   Title  \
# 0     140 அடி பிரம்மாண்ட முருகர்✨🤩| Malaysia Series ...
# 1     Game-ஏ வாய்-ல தான் 🙄🤣| Malaysia Virundhu | Ep ...
# 2     என் நெஞ்சில் குடியிருக்கும்...🤩 | Malaysia Vir...
# 3     Biriyani Ready, Are You Ready? 🍗🤩 | Malaysia V...
# 4     ஆஹா! அழ வச்சிருவாங்க போலையே🥺❤️ | Malaysia Viru...
# ...                                                 ...
# 1124  chart pattern analysis #sharmamotivationalvide...
# 1125  chart pattern analysis #chartpatterns #banknif...
# 1126  11-08-2022 nifty analysis #sharemarket #sharem...
# 1127  11-08-2022 analysis of market #sharemarkettoda...
# 1128                 nifty and banknifty for 25-07-2022
#
#                                                    Tags  \
# 0     [Vj Siddhu Vlogs, Vj Siddhu Vlogs channel, Sid...
# 1     [Vj Siddhu Vlogs, Vj Siddhu Vlogs channel, Sid...
# 2     [Vj Siddhu Vlogs, Vj Siddhu Vlogs channel, Sid...
# 3     [Vj Siddhu Vlogs, Vj Siddhu Vlogs channel, Sid...
# 4     [Vj Siddhu Vlogs, Vj Siddhu Vlogs channel, Sid...
# ...                                                 ...
# 1124                                               None
# 1125                                               None
# 1126                                               None
# 1127                                               None
# 1128                                               None
#
#                                            Thumbnail  \
# 0     https://i.ytimg.com/vi/dEyhsXExCQ4/default.jpg
# 1     https://i.ytimg.com/vi/AnZJvhR-TG0/default.jpg
# 2     https://i.ytimg.com/vi/U6Vzawt5pd8/default.jpg
# 3     https://i.ytimg.com/vi/GWx3nMbWOd8/default.jpg
# 4     https://i.ytimg.com/vi/lz-SC3NwSGY/default.jpg
# ...                                              ...
# 1124  https://i.ytimg.com/vi/A3qgW-Topgw/default.jpg
# 1125  https://i.ytimg.com/vi/CgkwyU5RZDg/default.jpg
# 1126  https://i.ytimg.com/vi/spT2RrBgGS8/default.jpg
# 1127  https://i.ytimg.com/vi/a-liBIa2OM0/default.jpg
# 1128  https://i.ytimg.com/vi/EmXhekpwXg4/default.jpg
#
#                                             Description        Published_Date  \
# 0     #vjsiddhuvlogs #malaysia #malaysiaseries #epis...  2024-11-15T09:30:07Z
# 1     #vjsiddhuvlogs #malaysia #malaysiavirundhu #ep...  2024-11-13T09:30:07Z
# 2     #vjsiddhuvlogs #malaysia #malaysiavirundhu #ep...  2024-11-11T09:30:08Z
# 3     #vjsiddhuvlogs #malaysia #malaysiavirundhu #ep...  2024-11-10T04:30:07Z
# 4     #vjsiddhuvlogs #malaysia #malaysiavirundhu #ep...  2024-11-08T09:30:07Z
# ...                                                 ...                   ...
# 1124                                                     2022-08-11T17:02:59Z
# 1125                                                     2022-08-11T16:50:05Z
# 1126                                                     2022-08-11T16:32:09Z
# 1127                                                     2022-08-11T16:29:02Z
# 1128                   this is only for education vedio  2022-07-23T06:07:30Z
#
#       Duration    Views   Likes Comments Favorite_Count Definition  \
# 0      PT15M5S   955935   93313      797              0         hd
# 1      PT6M48S  1039398   91079      925              0         hd
# 2     PT23M19S  1761715  139656     1561              0         hd
# 3      PT14M4S  1702696  133421     1028              0         hd
# 4     PT20M21S  1788172  154995     2130              0         hd
# ...        ...      ...     ...      ...            ...        ...
# 1124     PT55S       83    None        0              0         hd
# 1125     PT58S      114    None        0              0         hd
# 1126     PT57S        3    None        0              0         hd
# 1127    PT1M1S       21       4        0              0         hd
# 1128   PT4M10S       77       5        3              0         hd
#
#      Caption_Status
# 0             false
# 1              true
# 2              true
# 3              true
# 4              true
# ...             ...
# 1124          false
# 1125          false
# 1126          false
# 1127          false
# 1128          false
#
# [1129 rows x 15 columns]

# %% [markdown]
# ##### COMMENTS TABLE

# %%
def comments_table():
    mydb=psycopg2.connect(host="localhost",
                        user="postgres",
                        password="222005",
                        database="AK_data",
                        port="5432")
    cursor=mydb.cursor()

    drop_query = '''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()

    create_query='''create table if not exists comments(Comment_Id varchar(100) primary key,
                                                        Video_Id varchar(50),
                                                        Comment_Text text,
                                                        Comment_Author varchar(150),
                                                        Comment_Published timestamp
                                                        )'''

    cursor.execute(create_query)
    mydb.commit()

    com_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
            
    df3 = pd.DataFrame(com_list)

    for index,row in df3.iterrows():
            insert_query='''insert into comments(Comment_Id,
                                                    Video_Id,
                                                    Comment_Text,
                                                    Comment_Author,
                                                    Comment_Published
                                                )
                                                
                                                values(%s,%s,%s,%s,%s)'''
            
            
            values=(row['Comment_Id'],
                    row['Video_Id'],
                    row['Comment_Text'],
                    row['Comment_Author'],
                    row['Comment_Published']
                    )

            
            cursor.execute(insert_query,values)
            mydb.commit()

# %%
com_list = []
db = client["AK_data"]
coll1 = db["Akch_details"]

for com_data in coll1.find({},{"_id":0,"comment_information":1}):
    for i in range(len(com_data["comment_information"])):
        com_list.append(com_data["comment_information"][i])
        
df3 = pd.DataFrame(com_list)

# %%
df3
# Out:
#                        Comment_Id     Video_Id  \
# 0      Ugyef2cLn8C63Y7Ye6B4AaABAg  dEyhsXExCQ4
# 1      UgyOmQ0S4rBB1hRhDl94AaABAg  dEyhsXExCQ4
# 2      UgwpFUG_szFlh_D7nJp4AaABAg  dEyhsXExCQ4
# 3      Ugz-KBoJuvPDJR1dHyN4AaABAg  dEyhsXExCQ4
# 4      Ugyk7HtuHhwslM6J1g94AaABAg  dEyhsXExCQ4
# ...                           ...          ...
# 30275  UgyGtTvpTQVqpdxLoGJ4AaABAg  gYcndRcNvC8
# 30276  Ugyz3aISuUsV31N8kyp4AaABAg  gYcndRcNvC8
# 30277  UgxfuwhznT44n8fvbAt4AaABAg  gYcndRcNvC8
# 30278  UgwcvtO17RsxLYHhsG14AaABAg  gYcndRcNvC8
# 30279  Ugx7IfyiqKOJJcQA6Nl4AaABAg  gYcndRcNvC8
#
#                                             Comment_Text      Comment_Author  \
# 0      சித்து அண்ணா இந்த வீடியோ மிகவும் அருமையாக இருந...    @gowthampersonal
# 1                                                    ❤❤❤   @varalakshmij9439
# 2      <a href="https://www.youtube.com/watch?v=dEyhs...         @karthi1415
# 3                                          Om muruga om❤  @boopathianish6160
# 4              Malasiya murugara pathuten siddhu thanks😊  @Sujathakannan1981
# ...                                                  ...                 ...
# 30275                                     Best of luck 🎉   @kedaiMydin-jo7pq
# 30276  Sudhar , Gobi Anne vanthutte 5570 vathu subscr...    @aruarumugam2587
# 30277  Pin Me This channel will get 2 million subscri...         @reians7135
# 30278                     we are here to support you naa     @razlucifer1934
# 30279              Hi anna please hi mattum sollunga na❤     @dhanrajeeva279
#
#           Comment_Published
# 0      2024-11-16T04:38:21Z
# 1      2024-11-16T04:37:37Z
# 2      2024-11-16T04:37:13Z
# 3      2024-11-16T04:34:11Z
# 4      2024-11-16T04:32:46Z
# ...                     ...
# 30275  2024-06-20T08:18:01Z
# 30276  2024-06-20T07:12:57Z
# 30277  2024-06-20T07:11:41Z
# 30278  2024-06-20T07:01:09Z
# 30279  2024-06-20T06:57:49Z
#
# [30280 rows x 5 columns]

# %%
def tables():
    channels_table()
    playlist_table()
    videos_table()
    comments_table()
    
    return "Tables Created Successfully"

# %%
Tables = tables()

# %%
Tables
# Out:
# 'Tables Created Successfully'

# %%
def show_channels_table():
    ch_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_list.append(ch_data["channel_information"])
        
    df = st.dataframe(ch_list)
    
    return df

# %%
def show_playlists_table():
    pl_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for pl_data in coll1.find({},{"_id":0,"playlist_information":1}):
        for i in range(len(pl_data["playlist_information"])):
            pl_list.append(pl_data["playlist_information"][i])
            
    df1 = st.dataframe(pl_list)
    
    return df1

# %%
def show_videos_table():
    vi_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for vi_data in coll1.find({},{"_id":0,"video_information":1}):
        for i in range(len(vi_data["video_information"])):
            vi_list.append(vi_data["video_information"][i])
            
    df2 = st.dataframe(vi_list)
    
    return df2

# %%
def show_comments_table():
    com_list = []
    db = client["AK_data"]
    coll1 = db["Akch_details"]

    for com_data in coll1.find({},{"_id":0,"comment_information":1}):
        for i in range(len(com_data["comment_information"])):
            com_list.append(com_data["comment_information"][i])
            
    df3 = st.dataframe(com_list)
    
    return df3
